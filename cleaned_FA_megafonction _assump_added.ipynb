# %% [markdown]
# <h2>Assumptions Check</h2>
# <h3>Normality, collinearity and singularity</h3>
#
# <br>(c) Marie-Eve Picard, Maude Picard, Andreanne Proulx, 2021

# %% [markdown]
# <b>Description</b>
# <br>This script can be used to verified:
# <ul><li>Accuracy of the dataset</li>
# <li>Normality</li>
# <li>Collinearity</li></ul>
# <br>Steps for assumptions check are based on Tabachnick & Fidell, 2018

# %%
#import required modules
import pandas as pd 
import numpy as np
import scipy
import scipy.stats as stats
import math
import matplotlib
from matplotlib import pyplot as plt 
# %matplotlib inline
from scipy.spatial.distance import mahalanobis
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import seaborn as sns
sns.set_theme(style = "whitegrid")
import statsmodels.api as sm
from statsmodels.graphics.gofplots import ProbPlot
from factor_analyzer import FactorAnalyzer
from sklearn import preprocessing
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo

# %%
#set pandas option so that we can see the entire dataframe
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# <b>Import the dataset</b>

# %%
file_name = "C:/Users/mepic/OneDrive/Documents/Master/PSY6002/TP/donnees_tp1_v2.sav"
df = pd.read_spss(file_name)

# %% [markdown]
# <b>Accuracy of Data File</b>
# <br>Check for possible duplicated rows

# %%
#Overview of the dataset
df.head()
# Out:
#    Sujet     Genre   Age  MA1001  MA1012r  MA1023  MA1034r  MA1045  MA1056r  \
# 0    1.0  Masculin  15.0     4.0      4.0     2.0      6.0     3.0      4.0
# 1    2.0  Masculin  15.0     5.0      6.0     5.0      6.0     5.0      6.0
# 2    3.0   Féminin  14.0     5.0      6.0     3.0      6.0     3.0      6.0
# 3    4.0   Féminin  14.0     4.0      4.0     3.0      5.0     5.0      5.0
# 4    5.0   Féminin  14.0     6.0      6.0     5.0      6.0     3.0      6.0
#
#    MA1067  MA1078r  MA1089  MA1096r  PH2005  PH2027  PH2049  PH2071  ph2016r  \
# 0     4.0      6.0     4.0      4.0     6.0     6.0     6.0     5.0      6.0
# 1     5.0      6.0     5.0      6.0     5.0     5.0     4.0     4.0      6.0
# 2     5.0      6.0     3.0      6.0     5.0     5.0     5.0     6.0      6.0
# 3     5.0      6.0     5.0      5.0     2.0     5.0     6.0     6.0      6.0
# 4     6.0      6.0     4.0      6.0     4.0     4.0     1.0     4.0      4.0
#
#    ph2038r  ph2060r  ph2082r  VE1006r  VE1017  VE1028r  VE1039  VE1050r  \
# 0      6.0      6.0      6.0      2.0     2.0      3.0     1.0      5.0
# 1      6.0      6.0      6.0      5.0     1.0      5.0     2.0      6.0
# 2      6.0      6.0      6.0      6.0     5.0      6.0     6.0      6.0
# 3      5.0      6.0      6.0      6.0     3.0      6.0     6.0      6.0
# 4      5.0      4.0      4.0      5.0     3.0      5.0     5.0      5.0
#
#    VE1061  VE1072r  VE1083  VE1092r  VE1099  SS1009  SS1031  SS1053  SS1075  \
# 0     1.0      1.0     2.0      5.0     1.0     2.0     5.0     2.0     2.0
# 1     1.0      6.0     1.0      5.0     2.0     4.0     1.0     5.0     5.0
# 2     5.0      6.0     5.0      6.0     6.0     6.0     6.0     6.0     5.0
# 3     4.0      6.0     5.0      6.0     5.0     3.0     5.0     5.0     5.0
# 4     3.0      6.0     6.0      2.0     5.0     4.0     5.0     6.0     6.0
#
#    SS1094  ss1020r  ss1042r  ss1064r  ss1086r  ss1101r
# 0     2.0      5.0      3.0      3.0      4.0      4.0
# 1     5.0      6.0      5.0      5.0      5.0      5.0
# 2     5.0      6.0      6.0      6.0      6.0      6.0
# 3     5.0      6.0      6.0      6.0      6.0      6.0
# 4     6.0      6.0      6.0      6.0      6.0      6.0

# %%
#Overview of the columns in the dataset
df.columns
# Out:
# Index(['Sujet', 'Genre', 'Age', 'MA1001', 'MA1012r', 'MA1023', 'MA1034r',
#        'MA1045', 'MA1056r', 'MA1067', 'MA1078r', 'MA1089', 'MA1096r', 'PH2005',
#        'PH2027', 'PH2049', 'PH2071', 'ph2016r', 'ph2038r', 'ph2060r',
#        'ph2082r', 'VE1006r', 'VE1017', 'VE1028r', 'VE1039', 'VE1050r',
#        'VE1061', 'VE1072r', 'VE1083', 'VE1092r', 'VE1099', 'SS1009', 'SS1031',
#        'SS1053', 'SS1075', 'SS1094', 'ss1020r', 'ss1042r', 'ss1064r',
#        'ss1086r', 'ss1101r'],
#       dtype='object')

# %%
#Replace 88 or 99 for NaN in Age and Genre
def changeMissing(var):
    for i in range (len(df[var])):
        if df[var][i] == 88 or df[var][i] == 99:
            df[var][i] = None

changeMissing('Age')
changeMissing('Genre')

# %% [markdown]
# <b>Descriptive Stats with the original dataset (including missing values)</b>
# <ul><li>Mean & std</li>
# <li>Min & Max</li>
# <li>Number of missing</li></ul>

# %%
#Descriptive Stats (including missing values)

des1 = df_tp.describe(include = 'all')
des2 = df_tp.isnull().sum().to_frame(name = 'missing').T
df_des = pd.concat([des1, des2])
df_des
# Out:
#              MA1001     MA1012r      MA1023     MA1034r      MA1045  \
# count    619.000000  617.000000  618.000000  616.000000  613.000000
# mean       3.583199    3.627229    2.380259    4.003247    2.166395
# std        1.670448    1.772015    1.445744    1.643906    1.376167
# min        1.000000    1.000000    1.000000    1.000000    1.000000
# 25%        2.000000    2.000000    1.000000    3.000000    1.000000
# 50%        4.000000    4.000000    2.000000    4.000000    2.000000
# 75%        5.000000    5.000000    3.000000    5.000000    3.000000
# max        6.000000    6.000000    6.000000    6.000000    6.000000
# missing    6.000000    8.000000    7.000000    9.000000   12.000000
#
#             MA1056r      MA1067     MA1078r      MA1089     MA1096r  \
# count    620.000000  620.000000  616.000000  616.000000  619.000000
# mean       3.993548    3.758065    4.375000    3.569805    3.567044
# std        1.611737    1.619604    1.697619    1.656227    1.790829
# min        1.000000    1.000000    1.000000    1.000000    1.000000
# 25%        3.000000    2.000000    3.000000    2.000000    2.000000
# 50%        4.000000    4.000000    5.000000    4.000000    4.000000
# 75%        5.000000    5.000000    6.000000    5.000000    5.000000
# max        6.000000    6.000000    6.000000    6.000000    6.000000
# missing    5.000000    5.000000    9.000000    9.000000    6.000000
#
#              PH2005      PH2027      PH2049      PH2071     ph2016r  \
# count    614.000000  619.000000  617.000000  621.000000  619.000000
# mean       4.617264    4.495961    3.755267    3.900161    4.655897
# std        1.559613    1.520486    1.542707    1.597281    1.491999
# min        1.000000    1.000000    1.000000    1.000000    1.000000
# 25%        4.000000    4.000000    3.000000    3.000000    4.000000
# 50%        5.000000    5.000000    4.000000    4.000000    5.000000
# 75%        6.000000    6.000000    5.000000    5.000000    6.000000
# max        6.000000    6.000000    6.000000    6.000000    6.000000
# missing   11.000000    6.000000    8.000000    4.000000    6.000000
#
#             ph2038r     ph2060r     ph2082r     VE1006r      VE1017  \
# count    615.000000  621.000000  619.000000  620.000000  620.000000
# mean       4.609756    5.024155    5.048465    4.106452    2.569355
# std        1.493930    1.428194    1.358508    1.588007    1.484447
# min        1.000000    1.000000    1.000000    1.000000    1.000000
# 25%        4.000000    5.000000    5.000000    3.000000    1.000000
# 50%        5.000000    6.000000    6.000000    4.000000    2.000000
# 75%        6.000000    6.000000    6.000000    5.000000    4.000000
# max        6.000000    6.000000    6.000000    6.000000    6.000000
# missing   10.000000    4.000000    6.000000    5.000000    5.000000
#
#             VE1028r      VE1039     VE1050r      VE1061     VE1072r  \
# count    620.000000  616.000000  619.000000  619.000000  619.000000
# mean       4.096774    3.712662    4.268174    3.226171    3.893376
# std        1.526393    1.470657    1.556635    1.715311    1.843805
# min        1.000000    1.000000    1.000000    1.000000    1.000000
# 25%        3.000000    3.000000    3.000000    2.000000    2.000000
# 50%        4.000000    4.000000    5.000000    3.000000    4.000000
# 75%        5.000000    5.000000    6.000000    5.000000    6.000000
# max        6.000000    6.000000    6.000000    6.000000    6.000000
# missing    5.000000    9.000000    6.000000    6.000000    6.000000
#
#              VE1083     VE1092r      VE1099      SS1009      SS1031  \
# count    619.000000  619.000000  620.000000  620.000000  618.000000
# mean       3.882068    4.155089    4.027419    2.856452    4.574434
# std        1.492371    1.516421    1.443908    1.420041    1.465473
# min        1.000000    1.000000    1.000000    1.000000    1.000000
# 25%        3.000000    3.000000    3.000000    2.000000    4.000000
# 50%        4.000000    4.000000    4.000000    3.000000    5.000000
# 75%        5.000000    5.000000    5.000000    4.000000    6.000000
# max        6.000000    6.000000    6.000000    6.000000    6.000000
# missing    6.000000    6.000000    5.000000    5.000000    7.000000
#
#              SS1053      SS1075      SS1094     ss1020r     ss1042r  \
# count    618.000000  614.000000  616.000000  618.000000  615.000000
# mean       4.001618    4.197068    4.116883    4.606796    4.565854
# std        1.324864    1.249571    1.351653    1.463467    1.378690
# min        1.000000    1.000000    1.000000    1.000000    1.000000
# 25%        3.000000    4.000000    3.000000    4.000000    4.000000
# 50%        4.000000    4.000000    4.000000    5.000000    5.000000
# 75%        5.000000    5.000000    5.000000    6.000000    6.000000
# max        6.000000    6.000000    6.000000    6.000000    6.000000
# missing    7.000000   11.000000    9.000000    7.000000   10.000000
#
#             ss1064r     ss1086r     ss1101r
# count    617.000000  620.000000  620.000000
# mean       4.581848    4.535484    4.454839
# std        1.343646    1.342856    1.334115
# min        1.000000    1.000000    1.000000
# 25%        4.000000    4.000000    4.000000
# 50%        5.000000    5.000000    5.000000
# 75%        6.000000    6.000000    5.000000
# max        6.000000    6.000000    6.000000
# missing    8.000000    5.000000    5.000000

# %%
#Check the age, might explain the violation of the normality assumption
countAge = 0
for i in range (len(df['Age'])):
    if df['Age'][i] == 14 or df['Age'][i] == 15:
        countAge += 1

print("nb participants between 14 and 15: ", countAge, "; percentage between 14 and 15: ", 100*countAge/621)
# Out:
# nb participants between 14 and 15:  575 ; percentage between 14 and 15:  92.5925925925926

# %%
#Change the dataframe to include only the targeted variables
#In this case, remove :  Sujet, Genre and Age columns (the 3 first columns)
df_tp = df.drop(df.columns[[0 , 1 , 2]], axis = 1)
df_tp.head()
# Out:
#    MA1001  MA1012r  MA1023  MA1034r  MA1045  MA1056r  MA1067  MA1078r  MA1089  \
# 0     4.0      4.0     2.0      6.0     3.0      4.0     4.0      6.0     4.0
# 1     5.0      6.0     5.0      6.0     5.0      6.0     5.0      6.0     5.0
# 2     5.0      6.0     3.0      6.0     3.0      6.0     5.0      6.0     3.0
# 3     4.0      4.0     3.0      5.0     5.0      5.0     5.0      6.0     5.0
# 4     6.0      6.0     5.0      6.0     3.0      6.0     6.0      6.0     4.0
#
#    MA1096r  PH2005  PH2027  PH2049  PH2071  ph2016r  ph2038r  ph2060r  \
# 0      4.0     6.0     6.0     6.0     5.0      6.0      6.0      6.0
# 1      6.0     5.0     5.0     4.0     4.0      6.0      6.0      6.0
# 2      6.0     5.0     5.0     5.0     6.0      6.0      6.0      6.0
# 3      5.0     2.0     5.0     6.0     6.0      6.0      5.0      6.0
# 4      6.0     4.0     4.0     1.0     4.0      4.0      5.0      4.0
#
#    ph2082r  VE1006r  VE1017  VE1028r  VE1039  VE1050r  VE1061  VE1072r  \
# 0      6.0      2.0     2.0      3.0     1.0      5.0     1.0      1.0
# 1      6.0      5.0     1.0      5.0     2.0      6.0     1.0      6.0
# 2      6.0      6.0     5.0      6.0     6.0      6.0     5.0      6.0
# 3      6.0      6.0     3.0      6.0     6.0      6.0     4.0      6.0
# 4      4.0      5.0     3.0      5.0     5.0      5.0     3.0      6.0
#
#    VE1083  VE1092r  VE1099  SS1009  SS1031  SS1053  SS1075  SS1094  ss1020r  \
# 0     2.0      5.0     1.0     2.0     5.0     2.0     2.0     2.0      5.0
# 1     1.0      5.0     2.0     4.0     1.0     5.0     5.0     5.0      6.0
# 2     5.0      6.0     6.0     6.0     6.0     6.0     5.0     5.0      6.0
# 3     5.0      6.0     5.0     3.0     5.0     5.0     5.0     5.0      6.0
# 4     6.0      2.0     5.0     4.0     5.0     6.0     6.0     6.0      6.0
#
#    ss1042r  ss1064r  ss1086r  ss1101r
# 0      3.0      3.0      4.0      4.0
# 1      5.0      5.0      5.0      5.0
# 2      6.0      6.0      6.0      6.0
# 3      6.0      6.0      6.0      6.0
# 4      6.0      6.0      6.0      6.0

# %%
## Number of participants. However, 4 participants have no values at all
print ("Total number of participants is : " + str(len(df_tp)))
# Out:
# Total number of participants is : 625

# %%
#Compute % of missing values
nb_missing = df_des.loc['missing', : ].sum()
nb_tot = len(df_tp[df_tp.columns[0]]) * len(df_tp.columns)
print("% missing data: ", 100*nb_missing/nb_tot)
# Out:
# % missing data:  1.111578947368421

# %% [markdown]
# <b>Skewness & Kurtosis</b>

# %%
#calculate skewness
df_skew = df_tp.skew(axis = 0, skipna = True)

print(df_skew.shape)

df_skew = pd.DataFrame({'VI': df_skew.index, 'Value': df_skew.values})
print(df_skew)
# Out:
# (38,)
#          VI     Value
# 0    MA1001 -0.096437
# 1   MA1012r -0.148379
# 2    MA1023  0.782279
# 3   MA1034r -0.423821
# 4    MA1045  1.113721
# 5   MA1056r -0.454028
# 6    MA1067 -0.306995
# 7   MA1078r -0.808725
# 8    MA1089 -0.133841
# 9   MA1096r -0.139475
# 10   PH2005 -0.973525
# 11   PH2027 -0.891452
# 12   PH2049 -0.176365
# 13   PH2071 -0.343704
# 14  ph2016r -0.887436
# 15  ph2038r -1.001280
# 16  ph2060r -1.498974
# 17  ph2082r -1.564263
# 18  VE1006r -0.481315
# 19   VE1017  0.655379
# 20  VE1028r -0.434436
# 21   VE1039 -0.246066
# 22  VE1050r -0.558079
# 23   VE1061  0.155382
# 24  VE1072r -0.318346
# 25   VE1083 -0.444955
# 26  VE1092r -0.501622
# 27   VE1099 -0.393652
# 28   SS1009  0.322828
# 29   SS1031 -0.898773
# 30   SS1053 -0.489628
# 31   SS1075 -0.704260
# 32   SS1094 -0.677098
# 33  ss1020r -0.966274
# 34  ss1042r -0.968081
# 35  ss1064r -0.890119
# 36  ss1086r -0.885056
# 37  ss1101r -0.795628

# %%
#print min and max skewness values with the corresponding variables
print(df_skew.loc[df_skew['Value']==min(df_skew['Value']), 'VI'], "Score min skewness: ", min(df_skew['Value']), "\n", df_skew.loc[df_skew['Value']==max(df_skew['Value']), 'VI'], "Score max skewness: ", max(df_skew['Value']))
# Out:
# 17    ph2082r
# Name: VI, dtype: object Score min skewness:  -1.5642625073536935
#  4    MA1045
# Name: VI, dtype: object Score max skewness:  1.1137212635833538

# %%
#Calculate kurtosis
df_kurtosis = df_tp.kurtosis(axis = 0, skipna = True)
df_kurtosis = pd.DataFrame({'VI': df_kurtosis.index, 'Value': df_kurtosis.values})
print(df_kurtosis)
# Out:
#          VI     Value
# 0    MA1001 -1.133959
# 1   MA1012r -1.310943
# 2    MA1023 -0.414935
# 3   MA1034r -1.008112
# 4    MA1045  0.412055
# 5   MA1056r -0.898595
# 6    MA1067 -1.049520
# 7   MA1078r -0.605651
# 8    MA1089 -1.177056
# 9   MA1096r -1.316010
# 10   PH2005 -0.182872
# 11   PH2027 -0.175145
# 12   PH2049 -1.004780
# 13   PH2071 -0.977036
# 14  ph2016r -0.306934
# 15  ph2038r  0.015142
# 16  ph2060r  1.230690
# 17  ph2082r  1.641583
# 18  VE1006r -0.816748
# 19   VE1017 -0.564117
# 20  VE1028r -0.837755
# 21   VE1039 -0.833375
# 22  VE1050r -0.812985
# 23   VE1061 -1.209300
# 24  VE1072r -1.328264
# 25   VE1083 -0.686343
# 26  VE1092r -0.792653
# 27   VE1099 -0.705325
# 28   SS1009 -0.850784
# 29   SS1031 -0.122198
# 30   SS1053 -0.371680
# 31   SS1075  0.238609
# 32   SS1094 -0.089204
# 33  ss1020r  0.036152
# 34  ss1042r  0.297846
# 35  ss1064r  0.099940
# 36  ss1086r  0.107179
# 37  ss1101r  0.087681

# %%
#print min and max kurtosis values with the corresponding variables
print(df_kurtosis.loc[df_kurtosis['Value']==min(df_kurtosis['Value']), 'VI'], "Score min kurtosis: ", min(df_kurtosis['Value']), "\n", df_kurtosis.loc[df_kurtosis['Value']==max(df_kurtosis['Value']), 'VI'], "Score max kurtosis: ", max(df_kurtosis['Value']))
# Out:
# 24    VE1072r
# Name: VI, dtype: object Score min kurtosis:  -1.3282638965991718
#  17    ph2082r
# Name: VI, dtype: object Score max kurtosis:  1.6415829088811216

# %% [markdown]
# <b>Z scores (univariate outliers)</b>

# %%
#Create an empty new dataframe for zscores
df_zscores = pd.DataFrame(columns = df_tp.columns)

# %%
#Calculate z scores(univariate outliers) for all variables
i=0
while i < len(df_tp.columns):
    if df_tp.columns[i] == df_zscores.columns[i]:
        df_zscores[df_zscores.columns[i]] = stats.zscore(df_tp[df_tp.columns[i]], nan_policy='omit')
        i+=1
    else:
        print('error')
        break

# %%
#overview of the zscores dataframe
df_zscores.head()
# Out:
#      MA1001   MA1012r    MA1023   MA1034r    MA1045   MA1056r    MA1067  \
# 0  0.249716  0.210537 -0.263233  1.215626  0.606239  0.004006  0.149500
# 1  0.848842  1.340111  1.813504  1.215626  2.060737  1.245905  0.767433
# 2  0.848842  1.340111  0.429013  1.215626  0.606239  1.245905  0.767433
# 3  0.249716  0.210537  0.429013  0.606825  2.060737  0.624956  0.767433
# 4  1.447968  1.340111  1.813504  1.215626  0.606239  1.245905  1.385367
#
#     MA1078r    MA1089   MA1096r    PH2005    PH2027    PH2049    PH2071  \
# 0  0.958001  0.259955  0.241959  0.887312  0.989983  1.456242  0.689125
# 1  0.958001  0.864228  1.359663  0.245605  0.331767  0.158767  0.062556
# 2  0.958001 -0.344318  1.359663  0.245605  0.331767  0.807504  1.315693
# 3  0.958001  0.864228  0.800811 -1.679518  0.331767  1.456242  1.315693
# 4  0.958001  0.259955  1.359663 -0.396103 -0.326450 -1.787445  0.062556
#
#     ph2016r   ph2038r   ph2060r   ph2082r   VE1006r    VE1017   VE1028r  \
# 0  0.901603  0.931353  0.683823  0.700993 -1.327546 -0.383856 -0.719120
# 1  0.901603  0.931353  0.683823  0.700993  0.563140 -1.058052  0.592216
# 2  0.901603  0.931353  0.683823  0.700993  1.193368  1.638730  1.247884
# 3  0.901603  0.261432  0.683823  0.700993  1.193368  0.290339  1.247884
# 4 -0.439965  0.261432 -0.717676 -0.772401  0.563140  0.290339  0.592216
#
#      VE1039   VE1050r    VE1061   VE1072r    VE1083   VE1092r    VE1099  \
# 0 -1.846023  0.470513 -1.298873 -1.570511 -1.262146  0.557625 -2.098378
# 1 -1.165503  1.113444 -1.298873  1.143466 -1.932763  0.557625 -1.405254
# 2  1.556581  1.113444  1.034951  1.143466  0.749704  1.217606  1.367244
# 3  1.556581  1.113444  0.451495  1.143466  0.749704  1.217606  0.674119
# 4  0.876060  0.470513 -0.131961  1.143466  1.420321 -1.422317  0.674119
#
#      SS1009    SS1031    SS1053    SS1075    SS1094   ss1020r   ss1042r  \
# 0 -0.603604  0.290630 -1.512034 -1.759692 -1.567416  0.268897 -1.136679
# 1  0.805943 -2.441075  0.754183  0.643090  0.653891  0.952760  0.315154
# 2  2.215490  0.973557  1.509589  0.643090  0.653891  0.952760  1.041071
# 3  0.101169  0.290630  0.754183  0.643090  0.653891  0.952760  1.041071
# 4  0.805943  0.290630  1.509589  1.444017  1.394327  0.952760  1.041071
#
#     ss1064r   ss1086r   ss1101r
# 0 -1.178235 -0.399087 -0.341204
# 1  0.311460  0.346196  0.408961
# 2  1.056307  1.091479  1.159127
# 3  1.056307  1.091479  1.159127
# 4  1.056307  1.091479  1.159127

# %%
for i in range(len(df_zscores.columns)):
    v_min = df_zscores[df_zscores.columns[i]].min(skipna = True)
    v_max = df_zscores[df_zscores.columns[i]].max()
    print(df_zscores.columns[i], ": ", "min = ", v_min, " max = ", v_max)
# Out:
# MA1001 :  min =  -1.5476612662759246  max =  1.4479682641330727
# MA1012r :  min =  -1.4838251229763617  max =  1.3401110302513222
# MA1023 :  min =  -0.955477991236446  max =  2.5057494330550165
# MA1034r :  min =  -1.8283810480887837  max =  1.2156263184590295
# MA1045 :  min =  -0.8482598096906924  max =  2.787986787095282
# MA1056r :  min =  -1.8588424846364737  max =  1.2459051998317743
# MA1067 :  min =  -1.7043001259288475  max =  1.3853667690298817
# MA1078r :  min =  -1.98969416115299  max =  0.9580008924069952
# MA1089 :  min =  -1.5528633013559592  max =  1.4685005446177326
# MA1096r :  min =  -1.4345982196743283  max =  1.3596632591752913
# PH2005 :  min =  -2.3212250544463893  max =  0.8873120536807675
# PH2027 :  min =  -2.30109921783705  max =  0.9899830738476406
# PH2049 :  min =  -1.7874447737769177  max =  1.4562417715770768
# PH2071 :  min =  -1.8171499084959668  max =  1.3156932152574907
# ph2016r :  min =  -2.4523159188677655  max =  0.9016026710110387
# ph2038r :  min =  -2.418249002025364  max =  0.9313526561854446
# ph2060r :  min =  -2.8199239565613197  max =  0.6838230963089874
# ph2082r :  min =  -2.9824923011663427  max =  0.7009928034265664
# VE1006r :  min =  -1.957774089283234  max =  1.1933680066555123
# VE1017 :  min =  -1.0580519352454183  max =  2.312925453511824
# VE1028r :  min =  -2.0304561261363476  max =  1.2478844941879637
# VE1039 :  min =  -1.8460234583014044  max =  1.5565811207340987
# VE1050r :  min =  -2.1012106940545383  max =  1.1134443223067056
# VE1061 :  min =  -1.2988733957108294  max =  1.6184075619996328
# VE1072r :  min =  -1.570511335911703  max =  1.1434655399379459
# VE1083 :  min =  -1.9327630790518788  max =  1.4203208501328553
# VE1092r :  min =  -2.0822978293579717  max =  1.217605796787918
# VE1099 :  min =  -2.0983779992175458  max =  1.3672436297512298
# SS1009 :  min =  -1.3083778430737274  max =  2.2154895014341394
# SS1031 :  min =  -2.4410747350660995  max =  0.9735567413278557
# SS1053 :  min =  -2.267439836906502  max =  1.5095893253798005
# SS1075 :  min =  -2.5606194539790224  max =  1.4440171857130804
# SS1094 :  min =  -2.307852343682816  max =  1.3943274576417013
# ss1020r :  min =  -2.466551706201228  max =  0.9527595419646732
# ss1042r :  min =  -2.588512197961124  max =  1.041070569357826
# ss1064r :  min =  -2.6679304986353496  max =  1.0563073241203307
# ss1086r :  min =  -2.6349351481360452  max =  1.0914786106329972
# ss1101r :  min =  -2.591701339597224  max =  1.15912692966113

# %%
#Return index and columns where the zscore > 3.29, if no |zscores| > 3.29 in the entire dataframe: "no value exceeding 3.29"
ls_outliers=[]
for i in range(len(df_zscores.columns)):
    if df_zscores.loc[np.abs(df_zscores[df_zscores.columns[i]]) > 3.29].empty == False:
        df_zscores.loc[df_zscores[df_zscores.columns[i]] > 3.29]
        ls_outliers.append(True)

if len(ls_outliers) == 0:
    print("no zscores exceeding 3.29")
# Out:
# no zscores exceeding 3.29

# %%
#Z scores histograms for MA1001, PH2005, VE1006r, SS1009
var_interest = ['MA1001','PH2005','VE1006r','SS1009']
ls_color = ['blue', 'green', 'red', 'orange']

for i in range (len(var_interest)):
    plt.subplot(2,2,i+1)
    plt.hist(df_zscores[var_interest[i]], color = ls_color[i], edgecolor = 'black',bins = 6,range=(-3.29,3.29))
    plt.suptitle('Z scores')
    plt.xlabel(var_interest[i])
    plt.ylabel('Frequency')
    plt.tight_layout()

# %% [markdown]
# <b>Bivariate relationship linearity</b>
# <br>For TP1 only MA1001, PH2005, VE1006r and SS1009 will be tested for normality assumptions

# %% [markdown]
# Bivariate relationship between PH2005 (as the DV) and MA1001 (as the IV)

# %%
#Compute the scatter plot of the residuals

model1 = sm.OLS(df_tp.dropna()['PH2005'], sm.add_constant(df_tp.dropna()['MA1001'])).fit()
ypred1 = model1.predict()
standardized_yresid1 = preprocessing.scale(model1.resid)
standardized_ypred1 = preprocessing.scale(ypred1)
plt.scatter(standardized_ypred1, standardized_yresid1)
plt.plot([-1.53, 1.48],[0,0])
plt.suptitle('VD : PH2005 - VI : MA1001')
plt.xlabel('Régression Valeur prédite standardisée')
plt.ylabel('Régression Résiduel standardisé')
# Out:
# Text(0, 0.5, 'Régression Résiduel standardisé')

# %%
#Histogramm of the residuals

_, bins1, _ = plt.hist(standardized_yresid1, bins = 15, range=(-3,1), density = 1, alpha = 0.5)
mu1, sigma1 = stats.norm.fit(standardized_yresid1)
best_fit_line1 = stats.norm.pdf(bins1, mu1, sigma1)
plt.suptitle('Variable dépendante : PH2005')
plt.xlabel('Régression Résiduel standardisé')
plt.ylabel('Fréquence')
plt.plot(bins1, best_fit_line1)

# %% [markdown]
# Bivariate relationship between SS1009 (as the DV) and MA1001 (as the IV)

# %%
#Compute the scatter plot of the residuals

model2 = sm.OLS(df_tp.dropna()['SS1009'], sm.add_constant(df_tp.dropna()['MA1001'])).fit()
ypred2 = model2.predict()
standardized_yresid2 = preprocessing.scale(model2.resid)
standardized_ypred2 = preprocessing.scale(ypred2)
plt.scatter(standardized_ypred2, standardized_yresid2)
plt.plot([-1.51, 1.49], [0,0])
plt.suptitle('VD : SS1009 - VI : MA1001')
plt.xlabel('Régression Valeur prédite standardisée')
plt.ylabel('Régression Résiduel standardisé')
# Out:
# Text(0, 0.5, 'Régression Résiduel standardisé')

# %%
#Histogram of the residuals

_, bins2, _ = plt.hist(standardized_yresid2, bins = 15, range=(-3,3), density = 1, alpha = 0.5)
mu2, sigma2 = stats.norm.fit(standardized_yresid2)
best_fit_line2 = stats.norm.pdf(bins2, mu2, sigma2)
plt.suptitle('Variable dépendante : SS1009')
plt.xlabel('Régression Résiduel standardisé')
plt.ylabel('Fréquence')
plt.plot(bins2, best_fit_line2)

# %% [markdown]
# Bivariate relationship between VE1006r (as the DV) and MA1001 (as the IV)

# %%
#Compute de the scatter plot of the residuals

model3 = sm.OLS(df_tp.dropna()['VE1006r'], sm.add_constant(df_tp.dropna()['MA1001'])).fit()
ypred3 = model3.predict()
standardized_yresid3 = preprocessing.scale(model3.resid)
standardized_ypred3 = preprocessing.scale(ypred3)
plt.scatter(standardized_ypred3, standardized_yresid3)
plt.plot([-1.47, 1.52], [0,0])
plt.suptitle('VD : VE1006r - VI : MA1001')
plt.xlabel('Régression Valeur prédite standardisée')
plt.ylabel('Régression Résiduel standardisé')
# Out:
# Text(0, 0.5, 'Régression Résiduel standardisé')

# %%
#Histogram of the residuals

_, bins3, _ = plt.hist(standardized_yresid3, bins = 15, range=(-2.5, 1.5), density = 1, alpha = 0.5)
mu3, sigma3 = stats.norm.fit(standardized_yresid3)
best_fit_line3 = stats.norm.pdf(bins3, mu3, sigma3)
plt.suptitle('Variable dépendante : VE1006r')
plt.xlabel('Régression Résiduel standardisé')
plt.ylabel('Fréquence')
plt.plot(bins3, best_fit_line3)

# %% [markdown]
# Bivariate relationship between SS1009 (as the DV) and PH2005 (as the IV)

# %%
#Compute the scatter plot of the residuals

model4 = sm.OLS(df_tp.dropna()['SS1009'], sm.add_constant(df_tp.dropna()['PH2005'])).fit()
ypred4 = model4.predict()
standardized_yresid4 = preprocessing.scale(model4.resid)
standardized_ypred4 = preprocessing.scale(ypred4)
plt.scatter(standardized_ypred4, standardized_yresid4)
plt.plot([-2.45, 0.9], [0,0])
plt.suptitle('VD : SS1009 - VI : PH2005')
plt.xlabel('Régression Valeur prédite standardisée')
plt.ylabel('Régression Résiduel standardisé')
# Out:
# Text(0, 0.5, 'Régression Résiduel standardisé')

# %%
#Histogram of the residuals

_, bins4, _ = plt.hist(standardized_yresid4, bins = 15, range=(-2,3), density = 1, alpha = 0.5)
mu4, sigma4 = stats.norm.fit(standardized_yresid4)
best_fit_line4 = stats.norm.pdf(bins4, mu4, sigma4)
plt.suptitle('Variable dépendante : SS1009')
plt.xlabel('Régression Résiduel standardisé')
plt.ylabel('Fréquence')
plt.plot(bins4, best_fit_line4)

# %% [markdown]
# Bivariate relationship between VE1006r (as the DV) and PH2005 (as the IV)

# %%
#Compute the scatter plot of the residuals

model5 = sm.OLS(df_tp.dropna()['VE1006r'], sm.add_constant(df_tp.dropna()['PH2005'])).fit()
ypred5 = model5.predict()
standardized_yresid5 = preprocessing.scale(model5.resid)
standardized_ypred5 = preprocessing.scale(ypred5)
plt.scatter(standardized_ypred5, standardized_yresid5)
plt.plot([-0.9, 2.45],[0,0])
plt.suptitle('VD : VE1006r - VI : PH2005')
plt.xlabel('Régression Valeur prédite standardisée')
plt.ylabel('Régression Résiduel standardisé')
# Out:
# Text(0, 0.5, 'Régression Résiduel standardisé')

# %%
#Histogram of the residuals

_, bins5, _ = plt.hist(standardized_yresid5, bins = 15, range=(-2.5,1.5), density = 1, alpha = 0.5)
mu5, sigma5 = stats.norm.fit(standardized_yresid5)
best_fit_line5 = stats.norm.pdf(bins5, mu5, sigma5)
plt.suptitle('Variable dépendante : VE1006r')
plt.xlabel('Régression Résiduel standardisé')
plt.ylabel('Fréquence')
plt.plot(bins5, best_fit_line5)

# %% [markdown]
# Bivariate relationship between SS1009 (as the DV) and VE1006r (as the IV)

# %%
#Compute the scatter plot of the residuals

model6 = sm.OLS(df_tp.dropna()['SS1009'], sm.add_constant(df_tp.dropna()['VE1006r'])).fit()
ypred6 = model6.predict()
standardized_yresid6 = preprocessing.scale(model6.resid)
standardized_ypred6 = preprocessing.scale(ypred6)
plt.scatter(standardized_ypred6, standardized_yresid6)
plt.plot([-2,1.25], [0,0])
plt.suptitle('VD : SS1009 - VI : VE1006r')
plt.xlabel('Régression Valeur prédite standardisée')
plt.ylabel('Régression Résiduel standardisé')
# Out:
# Text(0, 0.5, 'Régression Résiduel standardisé')

# %%
#Histogram of the residuals

_, bins6, _ = plt.hist(standardized_yresid6, bins = 15, range=(-2,3), density = 1, alpha = 0.5)
mu6, sigma6 = stats.norm.fit(standardized_yresid6)
best_fit_line6 = stats.norm.pdf(bins6, mu6, sigma6)
plt.suptitle('Variable dépendante : SS1009')
plt.xlabel('Régression Résiduel standardisé')
plt.ylabel('Fréquence')
plt.plot(bins6, best_fit_line6)

# %% [markdown]
# <b>Multivariate outliers</b>

# %%
#Calculate multivariate outliers (mahalanobis distance)
#https://www.machinelearningplus.com/statistics/mahalanobis-distance/

def mahalanobis_outliers(x=None, data=None, cov=None):
    x_minus_mu = x - np.mean(data)
    if not cov:
        cov=np.cov(data.values.T)
    inv_covmat = scipy.linalg.inv(cov)
    left_term = np.dot(x_minus_mu, inv_covmat)
    mahal = np.dot(left_term, x_minus_mu.T)
    md = np.sqrt(mahal.diagonal())
    return md

df_mahal = df_tp.dropna()
df_mahal['mahal'] = mahalanobis_outliers(x = df_mahal, data = df_tp.dropna())
df_mahal['mahal_square'] = np.power((df_mahal['mahal']),2)

# %%
#Compute critical Chi2 value 
dfreedom = len(df_tp.columns) - 1
signlevel = 0.001
chi_critic = stats.chi2.ppf((1-signlevel), df = dfreedom)
chi_critic
# Out:
# 69.3464524962412

# %%
#If the value of D^2 is superior to the critical chi2 value, save i+1 (+1 because the indexes in python start at 0)
ls_multioutliers = []
for i in range (len(df_tp['MA1001'])):
    try:
        if df_mahal['mahal_square'][i] > chi_critic:
            ls_multioutliers.append(i+1)
    except:
        continue

# %%
#Print participant ID with multivariate outliers
ls_multioutliers
# Out:
# [6,
#  21,
#  53,
#  56,
#  76,
#  90,
#  149,
#  150,
#  159,
#  163,
#  164,
#  179,
#  188,
#  208,
#  245,
#  270,
#  302,
#  308,
#  328,
#  331,
#  341,
#  345,
#  359,
#  361,
#  398,
#  403,
#  427,
#  429,
#  448,
#  469,
#  485,
#  508,
#  518,
#  525,
#  526,
#  550,
#  552,
#  563,
#  579,
#  586,
#  599,
#  600,
#  605,
#  614,
#  619,
#  624]

# %%
#calculate the % of multivariate outliers in our dataframe
percent_multivaroutliers_all = 100*len(ls_multioutliers)/621
percent_multivaroutliers = 100*len(ls_multioutliers)/len(df_tp.dropna()['MA1001'])
print('percentage of extreme scores over the sample: ', percent_multivaroutliers_all)
print('percentage of extreme scores excluding missing data: ', percent_multivaroutliers)
# Out:
# percentage of extreme scores over the sample:  7.407407407407407
# percentage of extreme scores excluding missing data:  8.394160583941606

# %% [markdown]
# <b>Multicollinearity & Singularity</b>
# <br>VIF
# <br>Condition index and variance proportion

# %%
#Compute the VIF
#Add a constant to the dataframe
df_constant = add_constant(df_tp.dropna())

#Create a dataframe
vif_data = pd.DataFrame()
vif_data['Features'] = df_constant.columns
#Compute VIF for each IVs
vif_data['VIF'] = [variance_inflation_factor(df_constant.values, i) for i in range(len(df_constant.columns))]

print(vif_data)
# Out:
#    Features        VIF
# 0     const  44.470267
# 1    MA1001   4.645117
# 2   MA1012r   4.517904
# 3    MA1023   2.522463
# 4   MA1034r   3.555179
# 5    MA1045   1.794249
# 6   MA1056r   3.943988
# 7    MA1067   4.753229
# 8   MA1078r   1.982331
# 9    MA1089   3.676130
# 10  MA1096r   2.652681
# 11   PH2005   2.172180
# 12   PH2027   2.979575
# 13   PH2049   2.144046
# 14   PH2071   1.598443
# 15  ph2016r   1.944914
# 16  ph2038r   2.205183
# 17  ph2060r   1.912932
# 18  ph2082r   2.606851
# 19  VE1006r   2.382360
# 20   VE1017   1.908372
# 21  VE1028r   2.117178
# 22   VE1039   3.308328
# 23  VE1050r   2.014356
# 24   VE1061   3.337248
# 25  VE1072r   1.547188
# 26   VE1083   3.805453
# 27  VE1092r   1.273954
# 28   VE1099   3.834108
# 29   SS1009   1.659525
# 30   SS1031   1.327103
# 31   SS1053   2.547548
# 32   SS1075   3.484388
# 33   SS1094   3.395910
# 34  ss1020r   2.299870
# 35  ss1042r   3.249078
# 36  ss1064r   3.797424
# 37  ss1086r   3.286649
# 38  ss1101r   3.082910

# %%
#Compute the correlation matrix. By default, this function excludes NaN
#Check if the value is superior to 0.7 excluding the elements on the diagonal
df_corr = add_constant(df_tp.dropna()).corr(method = 'pearson')
for i in range(len(df_corr.columns)):
    for j in range(len(df_corr.index)):
        if df_corr.columns[i] != df_corr.index[j]:
            if df_corr[df_corr.columns[i]][j] > 0.7:
                print(df_corr.columns[i],", ", df_corr.index[j], ": ", df_corr[df_corr.columns[i]][j])
# Out:
# MA1001 ,  MA1012r :  0.7873272856563714
# MA1001 ,  MA1034r :  0.7209393274008458
# MA1001 ,  MA1056r :  0.7421111844873547
# MA1001 ,  MA1067 :  0.8108623204180944
# MA1001 ,  MA1089 :  0.7602587019857359
# MA1012r ,  MA1001 :  0.7873272856563714
# MA1012r ,  MA1034r :  0.7551930160442847
# MA1012r ,  MA1056r :  0.7739498152643273
# MA1012r ,  MA1067 :  0.7716846597832913
# MA1012r ,  MA1089 :  0.7551342467020831
# MA1034r ,  MA1001 :  0.7209393274008458
# MA1034r ,  MA1012r :  0.7551930160442847
# MA1034r ,  MA1056r :  0.7435056482622487
# MA1034r ,  MA1067 :  0.7263584477806709
# MA1034r ,  MA1089 :  0.7093110717636704
# MA1056r ,  MA1001 :  0.7421111844873547
# MA1056r ,  MA1012r :  0.7739498152643273
# MA1056r ,  MA1034r :  0.7435056482622487
# MA1056r ,  MA1067 :  0.7774845951064028
# MA1067 ,  MA1001 :  0.8108623204180944
# MA1067 ,  MA1012r :  0.7716846597832913
# MA1067 ,  MA1034r :  0.7263584477806709
# MA1067 ,  MA1056r :  0.7774845951064028
# MA1067 ,  MA1089 :  0.7588770727865118
# MA1089 ,  MA1001 :  0.7602587019857359
# MA1089 ,  MA1012r :  0.7551342467020831
# MA1089 ,  MA1034r :  0.7093110717636704
# MA1089 ,  MA1067 :  0.7588770727865118
# VE1039 ,  VE1061 :  0.7081631634648722
# VE1039 ,  VE1083 :  0.7170248351708509
# VE1039 ,  VE1099 :  0.7531744244566126
# VE1061 ,  VE1039 :  0.7081631634648722
# VE1061 ,  VE1083 :  0.7284072978685563
# VE1083 ,  VE1039 :  0.7170248351708509
# VE1083 ,  VE1061 :  0.7284072978685563
# VE1083 ,  VE1099 :  0.7667855942555176
# VE1099 ,  VE1039 :  0.7531744244566126
# VE1099 ,  VE1083 :  0.7667855942555176
# SS1075 ,  SS1094 :  0.7694861723307549
# SS1094 ,  SS1075 :  0.7694861723307549
# ss1042r ,  ss1064r :  0.7572299360103886
# ss1042r ,  ss1086r :  0.7062109604217016
# ss1064r ,  ss1042r :  0.7572299360103886
# ss1064r ,  ss1086r :  0.7530410562771015
# ss1086r ,  ss1042r :  0.7062109604217016
# ss1086r ,  ss1064r :  0.7530410562771015

# %% [markdown]
# #### Determinant of correlation matrix

# %%
def compute_determinant_corr(df):
    x_corr = df.corr()
    corr_det = np.linalg.det(x_corr)
    return print(corr_det)

compute_determinant_corr(df)
# Out:
# 2.274498499932741e-12

# %% [markdown]
# > Le coefficient devrait être plus grand que .00001, mais ici il est plus petit. Ici, le déterminant est très petit (multicolinéarité) pcq mesure tous estime de soi. Mais pas surprenant, simplement le mentionner dans la discussion. C'est une limitation.

# %% [markdown]
# ### Factorability

# %% [markdown]
# #### KMO

# %%
df = df_tp.dropna() # drop NAN

# %%
def compute_kmo(df):
    kmo_all,kmo_model=calculate_kmo(df)
    print ("kmo score : " + str(kmo_model))

compute_kmo(df)
# Out:
# kmo score : 0.9406666321035712

# %% [markdown]
# >  0,94 : adequate for factor analysis, des valeurs au-dessus de .6 sont requises.  (Tabachnick & Fidel, 2013; au-dessus de .5 selon Williams, Onsman & Brown, 2010

# %% [markdown]
# #### Test de Barlett

# %%
# Berlett test

def compute_berlett(df):
    chi_square_value,p_value=calculate_bartlett_sphericity(df)
    return print ("pval: " + str(p_value) + " /chi_square: " + str(chi_square_value))


compute_berlett(df)
# Out:
# pval: 0.0 /chi_square: 14339.769345672797

# %% [markdown]
# > La différence entre matrice de corrélation et matrice d'identité doit être significative, ici pval est de 0.0 donc significatif

# %% [markdown]
# #### Correlation matrix

# %%
### Plot correlation matrix 
import seaborn as sns

plt.figure(figsize=(25,25))

# plot the heatmap for correlation matrix
correlation_matrix = df.corr()
mask = np.zeros_like(correlation_matrix)
mask[np.triu_indices_from(mask)] = True

ax = sns.heatmap(correlation_matrix, 
                 vmin=-1, vmax=1, center=0,
                 cmap=sns.diverging_palette(220, 20, n=200),
                 mask=mask, square=True, 
                 annot=True, fmt='.2f')

# %%
columns = correlation_matrix.columns

# %%
# check if at least one value > 0.30
bool_corr = correlation_matrix > 0.30
bool_corr
# Out:
#          MA1001  MA1012r  MA1023  MA1034r  MA1045  MA1056r  MA1067  MA1078r  \
# MA1001     True     True    True     True    True     True    True     True
# MA1012r    True     True    True     True   False     True    True     True
# MA1023     True     True    True     True    True     True    True     True
# MA1034r    True     True    True     True    True     True    True     True
# MA1045     True    False    True     True    True     True    True     True
# MA1056r    True     True    True     True    True     True    True     True
# MA1067     True     True    True     True    True     True    True     True
# MA1078r    True     True    True     True    True     True    True     True
# MA1089     True     True    True     True    True     True    True     True
# MA1096r    True     True    True     True    True     True    True     True
# PH2005    False    False   False    False   False    False   False    False
# PH2027    False    False   False    False   False    False   False    False
# PH2049    False    False   False    False   False    False   False    False
# PH2071    False    False   False    False   False    False   False    False
# ph2016r   False    False   False    False   False    False   False    False
# ph2038r   False    False   False    False   False    False   False    False
# ph2060r   False    False   False    False   False    False   False    False
# ph2082r   False    False   False    False   False    False   False    False
# VE1006r   False    False   False    False   False    False   False    False
# VE1017    False    False   False    False   False    False   False    False
# VE1028r   False    False   False    False   False    False   False    False
# VE1039    False    False   False    False   False    False   False    False
# VE1050r   False    False   False    False   False    False   False    False
# VE1061    False    False   False    False   False    False   False    False
# VE1072r   False    False   False    False   False    False   False    False
# VE1083    False    False   False    False   False    False   False    False
# VE1092r   False    False   False    False   False    False   False    False
# VE1099    False    False   False    False   False    False   False    False
# SS1009     True     True    True     True    True     True    True     True
# SS1031    False    False   False     True   False    False    True    False
# SS1053     True     True    True     True   False     True    True     True
# SS1075     True     True   False     True   False     True    True     True
# SS1094     True     True    True     True   False     True    True     True
# ss1020r    True     True   False     True   False     True    True    False
# ss1042r    True     True    True     True   False     True    True    False
# ss1064r    True     True   False     True   False     True    True     True
# ss1086r    True     True   False     True   False     True    True    False
# ss1101r    True     True    True     True   False     True    True     True
#
#          MA1089  MA1096r  PH2005  PH2027  PH2049  PH2071  ph2016r  ph2038r  \
# MA1001     True     True   False   False   False   False    False    False
# MA1012r    True     True   False   False   False   False    False    False
# MA1023     True     True   False   False   False   False    False    False
# MA1034r    True     True   False   False   False   False    False    False
# MA1045     True     True   False   False   False   False    False    False
# MA1056r    True     True   False   False   False   False    False    False
# MA1067     True     True   False   False   False   False    False    False
# MA1078r    True     True   False   False   False   False    False    False
# MA1089     True     True   False   False   False   False    False    False
# MA1096r    True     True   False   False   False   False    False    False
# PH2005    False    False    True    True    True   False     True     True
# PH2027    False    False    True    True    True    True     True     True
# PH2049    False    False    True    True    True    True     True     True
# PH2071    False    False   False    True    True    True     True     True
# ph2016r   False    False    True    True    True    True     True     True
# ph2038r   False    False    True    True    True    True     True     True
# ph2060r   False    False    True    True    True    True     True     True
# ph2082r   False    False    True    True    True    True     True     True
# VE1006r   False    False   False   False   False   False    False    False
# VE1017    False    False   False   False   False   False    False    False
# VE1028r   False    False   False   False   False   False    False    False
# VE1039    False    False   False   False   False   False    False    False
# VE1050r   False    False   False   False   False   False    False    False
# VE1061    False    False   False   False   False   False    False    False
# VE1072r   False    False   False   False   False   False    False    False
# VE1083    False    False   False   False   False   False    False    False
# VE1092r   False    False   False   False   False   False    False    False
# VE1099    False    False   False   False   False   False    False    False
# SS1009     True     True   False   False   False   False    False    False
# SS1031    False     True   False   False   False   False    False    False
# SS1053     True     True   False   False   False   False    False    False
# SS1075     True     True   False   False   False   False    False    False
# SS1094     True     True   False   False   False   False    False    False
# ss1020r    True     True   False   False   False   False    False    False
# ss1042r    True     True   False   False   False   False    False    False
# ss1064r    True     True   False   False   False   False    False    False
# ss1086r    True     True   False   False   False   False    False    False
# ss1101r    True     True   False   False   False   False    False    False
#
#          ph2060r  ph2082r  VE1006r  VE1017  VE1028r  VE1039  VE1050r  VE1061  \
# MA1001     False    False    False   False    False   False    False   False
# MA1012r    False    False    False   False    False   False    False   False
# MA1023     False    False    False   False    False   False    False   False
# MA1034r    False    False    False   False    False   False    False   False
# MA1045     False    False    False   False    False   False    False   False
# MA1056r    False    False    False   False    False   False    False   False
# MA1067     False    False    False   False    False   False    False   False
# MA1078r    False    False    False   False    False   False    False   False
# MA1089     False    False    False   False    False   False    False   False
# MA1096r    False    False    False   False    False   False    False   False
# PH2005      True     True    False   False    False   False    False   False
# PH2027      True     True    False   False    False   False    False   False
# PH2049      True     True    False   False    False   False    False   False
# PH2071      True     True    False   False    False   False    False   False
# ph2016r     True     True    False   False    False   False    False   False
# ph2038r     True     True    False   False    False   False    False   False
# ph2060r     True     True    False   False    False   False    False   False
# ph2082r     True     True    False   False    False   False    False   False
# VE1006r    False    False     True    True     True    True     True    True
# VE1017     False    False     True    True    False    True    False    True
# VE1028r    False    False     True   False     True    True     True    True
# VE1039     False    False     True    True     True    True     True    True
# VE1050r    False    False     True   False     True    True     True    True
# VE1061     False    False     True    True     True    True     True    True
# VE1072r    False    False     True   False     True    True     True    True
# VE1083     False    False     True    True     True    True     True    True
# VE1092r    False    False    False   False    False   False    False   False
# VE1099     False    False     True    True     True    True     True    True
# SS1009     False    False    False   False    False   False    False   False
# SS1031     False    False    False   False    False   False    False   False
# SS1053     False    False    False   False    False    True    False   False
# SS1075     False    False     True   False    False    True    False    True
# SS1094     False    False     True   False     True    True    False    True
# ss1020r    False    False    False   False     True    True     True   False
# ss1042r    False    False     True   False     True    True     True   False
# ss1064r    False    False     True   False     True    True     True    True
# ss1086r    False    False     True   False     True    True     True    True
# ss1101r    False    False    False   False     True    True     True   False
#
#          VE1072r  VE1083  VE1092r  VE1099  SS1009  SS1031  SS1053  SS1075  \
# MA1001     False   False    False   False    True   False    True    True
# MA1012r    False   False    False   False    True   False    True    True
# MA1023     False   False    False   False    True   False    True   False
# MA1034r    False   False    False   False    True    True    True    True
# MA1045     False   False    False   False    True   False   False   False
# MA1056r    False   False    False   False    True   False    True    True
# MA1067     False   False    False   False    True    True    True    True
# MA1078r    False   False    False   False    True   False    True    True
# MA1089     False   False    False   False    True   False    True    True
# MA1096r    False   False    False   False    True    True    True    True
# PH2005     False   False    False   False   False   False   False   False
# PH2027     False   False    False   False   False   False   False   False
# PH2049     False   False    False   False   False   False   False   False
# PH2071     False   False    False   False   False   False   False   False
# ph2016r    False   False    False   False   False   False   False   False
# ph2038r    False   False    False   False   False   False   False   False
# ph2060r    False   False    False   False   False   False   False   False
# ph2082r    False   False    False   False   False   False   False   False
# VE1006r     True    True    False    True   False   False   False    True
# VE1017     False    True    False    True   False   False   False   False
# VE1028r     True    True    False    True   False   False   False   False
# VE1039      True    True    False    True   False   False    True    True
# VE1050r     True    True    False    True   False   False   False   False
# VE1061      True    True    False    True   False   False   False    True
# VE1072r     True    True    False    True   False   False    True    True
# VE1083      True    True    False    True   False   False    True    True
# VE1092r    False   False     True   False   False   False   False   False
# VE1099      True    True    False    True    True   False    True    True
# SS1009     False   False    False    True    True   False    True    True
# SS1031     False   False    False   False   False    True    True    True
# SS1053      True    True    False    True    True    True    True    True
# SS1075      True    True    False    True    True    True    True    True
# SS1094      True    True    False    True    True    True    True    True
# ss1020r    False    True    False    True    True    True    True    True
# ss1042r     True    True    False    True    True    True    True    True
# ss1064r     True    True    False    True    True    True    True    True
# ss1086r    False    True    False    True    True    True    True    True
# ss1101r    False    True    False    True    True    True    True    True
#
#          SS1094  ss1020r  ss1042r  ss1064r  ss1086r  ss1101r
# MA1001     True     True     True     True     True     True
# MA1012r    True     True     True     True     True     True
# MA1023     True    False     True    False    False     True
# MA1034r    True     True     True     True     True     True
# MA1045    False    False    False    False    False    False
# MA1056r    True     True     True     True     True     True
# MA1067     True     True     True     True     True     True
# MA1078r    True    False    False     True    False     True
# MA1089     True     True     True     True     True     True
# MA1096r    True     True     True     True     True     True
# PH2005    False    False    False    False    False    False
# PH2027    False    False    False    False    False    False
# PH2049    False    False    False    False    False    False
# PH2071    False    False    False    False    False    False
# ph2016r   False    False    False    False    False    False
# ph2038r   False    False    False    False    False    False
# ph2060r   False    False    False    False    False    False
# ph2082r   False    False    False    False    False    False
# VE1006r    True    False     True     True     True    False
# VE1017    False    False    False    False    False    False
# VE1028r    True     True     True     True     True     True
# VE1039     True     True     True     True     True     True
# VE1050r   False     True     True     True     True     True
# VE1061     True    False    False     True     True    False
# VE1072r    True    False     True     True    False    False
# VE1083     True     True     True     True     True     True
# VE1092r   False    False    False    False    False    False
# VE1099     True     True     True     True     True     True
# SS1009     True     True     True     True     True     True
# SS1031     True     True     True     True     True     True
# SS1053     True     True     True     True     True     True
# SS1075     True     True     True     True     True     True
# SS1094     True     True     True     True     True     True
# ss1020r    True     True     True     True     True     True
# ss1042r    True     True     True     True     True     True
# ss1064r    True     True     True     True     True     True
# ss1086r    True     True     True     True     True     True
# ss1101r    True     True     True     True     True     True

# %% [markdown]
# > Plusieurs corrélations > 0.30. The expected size depends, to some extent, on N (larger sample sizes tend to produce smaller correlations), but if no correlation exceeds .30, use of FA is questionable because there is probably nothing to factor analyze. Inspect R for correlations in excess of .30, and, if none is found, reconsider use of FA.(Tabachnick & Fidell)

# %% [markdown]
# ### Communalities (moyenne des représentations initiales)

# %%
def compute_communalities_initial (df, col):
    
    X = df.loc[ : , df.columns != col]
    y = pd.DataFrame({col:df[col]})
    X = sm.add_constant(X)
    results = sm.OLS(y, X).fit()
    rsquared = results.rsquared
    
    return rsquared

def compute_mean_communalities (communalities_1D):
    mean = "La moyenne des représentation initiales {}".format(communalities_1D.mean())
    
    return mean

# %%
r2 = []
for col in df.columns :
    
    rsquared = compute_communalities_initial(df, col)
    r2.append(rsquared)
    
repr_quality = pd.DataFrame()
repr_quality ["variable"] = df.columns 
repr_quality ["communalities"] = r2 

repr_quality
# Out:
#    variable  communalities
# 0    MA1001       0.784720
# 1   MA1012r       0.778658
# 2    MA1023       0.603562
# 3   MA1034r       0.718720
# 4    MA1045       0.442664
# 5   MA1056r       0.746450
# 6    MA1067       0.789617
# 7   MA1078r       0.495543
# 8    MA1089       0.727975
# 9   MA1096r       0.623023
# 10   PH2005       0.539633
# 11   PH2027       0.664382
# 12   PH2049       0.533592
# 13   PH2071       0.374391
# 14  ph2016r       0.485838
# 15  ph2038r       0.546523
# 16  ph2060r       0.477242
# 17  ph2082r       0.616395
# 18  VE1006r       0.580248
# 19   VE1017       0.475993
# 20  VE1028r       0.527673
# 21   VE1039       0.697732
# 22  VE1050r       0.503564
# 23   VE1061       0.700352
# 24  VE1072r       0.353666
# 25   VE1083       0.737219
# 26  VE1092r       0.215042
# 27   VE1099       0.739183
# 28   SS1009       0.397418
# 29   SS1031       0.246479
# 30   SS1053       0.607466
# 31   SS1075       0.713006
# 32   SS1094       0.705528
# 33  ss1020r       0.565193
# 34  ss1042r       0.692220
# 35  ss1064r       0.736664
# 36  ss1086r       0.695739
# 37  ss1101r       0.675631

# %%
# Moyenne de la qualité des représentation initiale 
compute_mean_communalities (repr_quality["communalities"])
# Out:
# 'La moyenne des représentation initiales 0.592498555682566'

# %% [markdown]
# > La qualité de la représentation est < 0.7 , McCallum et al., 1999, valeur recommandée. Nous prenons ici la décision de retirer les items < 0.3 pour augmenter la qualité des représentations

# %% [markdown]
# ### Remove items with initial communality < 0.3

# %% [markdown]
# *Item 1*

# %%
communalities = repr_quality["communalities"]

ft_comm_crit = list(communalities[communalities < 0.3].sort_values(0).index)
rmv_item = [*range(0,len(ft_comm_crit), 1)]
col_rmv_item = repr_quality["variable"][repr_quality.index == ft_comm_crit[0]]
df_rmv = df.drop(columns = col_rmv_item)

print("Item removed is index {}".format(col_rmv_item))
# Out:
# Item removed is index 26    VE1092r
# Name: variable, dtype: object

# %% [markdown]
# > Recalculons maintenant la qualité des représentation initiale (moyenne)

# %%
r2 = []
for col in df_rmv.columns :
    
    rsquared = compute_communalities_initial(df_rmv, col)
    r2.append(rsquared)
    
repr_quality_item1rmv = pd.DataFrame()
repr_quality_item1rmv ["variable"] = df_rmv.columns 
repr_quality_item1rmv ["communalities"] = r2 

repr_quality_item1rmv
# Out:
#    variable  communalities
# 0    MA1001       0.784695
# 1   MA1012r       0.777441
# 2    MA1023       0.602409
# 3   MA1034r       0.717651
# 4    MA1045       0.442231
# 5   MA1056r       0.746441
# 6    MA1067       0.789411
# 7   MA1078r       0.495457
# 8    MA1089       0.722488
# 9   MA1096r       0.621898
# 10   PH2005       0.539200
# 11   PH2027       0.662700
# 12   PH2049       0.533274
# 13   PH2071       0.354263
# 14  ph2016r       0.485268
# 15  ph2038r       0.544197
# 16  ph2060r       0.477226
# 17  ph2082r       0.616300
# 18  VE1006r       0.580219
# 19   VE1017       0.475266
# 20  VE1028r       0.525301
# 21   VE1039       0.697531
# 22  VE1050r       0.501042
# 23   VE1061       0.697190
# 24  VE1072r       0.353613
# 25   VE1083       0.736873
# 26   VE1099       0.739055
# 27   SS1009       0.396078
# 28   SS1031       0.246450
# 29   SS1053       0.606509
# 30   SS1075       0.712926
# 31   SS1094       0.705466
# 32  ss1020r       0.564732
# 33  ss1042r       0.692180
# 34  ss1064r       0.735519
# 35  ss1086r       0.695722
# 36  ss1101r       0.674563

# %%
compute_mean_communalities (repr_quality_item1rmv["communalities"])
# Out:
# 'La moyenne des représentation initiales 0.6013185444515361'

# %% [markdown]
# > Continuons jusqu'à ne plus avoir d'items dont la qtl de représentation initiale est < 0.30

# %% [markdown]
# *Item 2*

# %%
communalities = repr_quality_item1rmv["communalities"]

ft_comm_crit = list(communalities[communalities < 0.3].sort_values(0).index)
rmv_item = [*range(0,len(ft_comm_crit), 1)]
col_rmv_item = repr_quality_item1rmv["variable"][repr_quality_item1rmv.index == ft_comm_crit[0]]
df_rmv_item2 = df_rmv.drop(columns = col_rmv_item)

print("Item removed is index {}".format(col_rmv_item))
# Out:
# Item removed is index 28    SS1031
# Name: variable, dtype: object

# %%
r2 = []
for col in df_rmv_item2.columns :
    
    rsquared = compute_communalities_initial(df_rmv_item2, col)
    r2.append(rsquared)
    
repr_quality_item2rmv = pd.DataFrame()
repr_quality_item2rmv ["variable"] = df_rmv_item2.columns 
repr_quality_item2rmv ["communalities"] = r2 

repr_quality_item2rmv
# Out:
#    variable  communalities
# 0    MA1001       0.783474
# 1   MA1012r       0.777369
# 2    MA1023       0.601823
# 3   MA1034r       0.717077
# 4    MA1045       0.442010
# 5   MA1056r       0.746298
# 6    MA1067       0.789251
# 7   MA1078r       0.494271
# 8    MA1089       0.722060
# 9   MA1096r       0.619051
# 10   PH2005       0.539141
# 11   PH2027       0.662687
# 12   PH2049       0.532516
# 13   PH2071       0.354101
# 14  ph2016r       0.484732
# 15  ph2038r       0.544131
# 16  ph2060r       0.475550
# 17  ph2082r       0.614207
# 18  VE1006r       0.580214
# 19   VE1017       0.473550
# 20  VE1028r       0.523928
# 21   VE1039       0.697063
# 22  VE1050r       0.500667
# 23   VE1061       0.696201
# 24  VE1072r       0.352056
# 25   VE1083       0.736314
# 26   VE1099       0.739019
# 27   SS1009       0.396073
# 28   SS1053       0.601011
# 29   SS1075       0.712173
# 30   SS1094       0.704963
# 31  ss1020r       0.564162
# 32  ss1042r       0.692073
# 33  ss1064r       0.734900
# 34  ss1086r       0.695551
# 35  ss1101r       0.674412

# %%
qlt_repr_init = compute_mean_communalities (repr_quality_item2rmv["communalities"])
qlt_repr_init
# Out:
# 'La moyenne des représentation initiales 0.6103910391235944'

# %%
communalities = repr_quality_item2rmv["communalities"]
ft_comm_crit = list(communalities[communalities < 0.3].sort_values(0).index)

if ft_comm_crit == []:
    print("Il n'y a plus d'items avec une qualité de représentation initiale plus faible que 0,3")
else: 
    print ("Continuer à retirer des items")
# Out:
# Il n'y a plus d'items avec une qualité de représentation initiale plus faible que 0,3

# %% [markdown]
# > Avant de continuer, il est nécessaire de recalculer le déterminant, kmo et barlett avec le nouveau dataframe, duquel a été retiré items avec de plus faibles représentations

# %%
compute_determinant_corr(df_rmv_item2)
compute_kmo(df_rmv_item2)
compute_berlett(df_rmv_item2)
# Out:
# 3.84527637226869e-12
# kmo score : 0.9401825420134133
# pval: 0.0 /chi_square: 14075.25378364041

# %% [markdown]
# > Postulat de factorabilité est toujours respecté, poursuivons.

# %% [markdown]
# ### Méthode d'extraction et justification

# %% [markdown]
# Nous avons choisi ML, puisqu'étant donné le postulat de normalité varié, cette méthode donne moins de poids au items plus faible, considère l'erreur échantillonnage.

# %% [markdown]
# ### Pick n factors

# %% [markdown]
# #### Critère de Kaiser

# %%
def check_kaiser (n_factor, method, df):
    
    fa = FactorAnalyzer(n_factors=n_factor, rotation=None, method=method)
    fa.fit(df)
    
    # Get Eigenvalues
    ev, v = fa.get_eigenvalues()
    
    df_ev = pd.DataFrame(data = ev).rename(columns = {0: "eigenvalues"})
    df_ev.index = df_ev.index + 1
    
    return ev, df_ev


ev, df_ev = check_kaiser (25, "ml", df_rmv_item2)
df_ev
# Out:
#     eigenvalues
# 1     11.138797
# 2      5.522202
# 3      4.089780
# 4      1.653834
# 5      1.151814
# 6      1.048644
# 7      0.890933
# 8      0.785026
# 9      0.699901
# 10     0.612056
# 11     0.557549
# 12     0.534713
# 13     0.493285
# 14     0.489553
# 15     0.465200
# 16     0.443668
# 17     0.434225
# 18     0.398563
# 19     0.389121
# 20     0.360514
# 21     0.340516
# 22     0.331948
# 23     0.312983
# 24     0.299779
# 25     0.290045
# 26     0.270185
# 27     0.248128
# 28     0.241363
# 29     0.233153
# 30     0.216358
# 31     0.209546
# 32     0.187827
# 33     0.180213
# 34     0.174298
# 35     0.170578
# 36     0.133706

# %%
# Critère de Kaiser:  factors greater than 1. However note it tends to overextract the number of factors

nb_factors = df_ev[df_ev['eigenvalues'] < 1].index[0]-1
print ("The maximum number of factors (eigenvalues greater than 1) is  " + str(nb_factors))
# Out:
# The maximum number of factors (eigenvalues greater than 1) is  6

# %% [markdown]
# #### Test coude Cattell

# %%
# plot
def scree_plot(df, ev):
    plt.scatter(range(1,df.shape[1]+1),ev)
    plt.plot(range(1,df.shape[1]+1),ev)
    plt.title('Scree Plot')
    plt.xlabel('Factors')
    plt.ylabel('Eigenvalue')
    plt.grid()
    
    return plt.show()

scree_plot(df_rmv_item2, ev)

# %% [markdown]
# > Keep factors before inflexion point. Eigenvalues for the first four factors are larger, and, after the fourth factor, changes in successive eigenvalues are small.
#
# > This is taken as evidence that there are probably between four and six factors. The scree plot visually suggests breaks between four factors.
#
# > Results from scree plot are consistent with earlier research suggesting four factors on the questionnaire.
#
# > Note scree plot is more subjective. We will look at solutions for [4,5,6] factors to decide upon best n factors.

# %% [markdown]
# ### Evaluate the quality of FA solutions for [4,5,6] n factors

# %%
# Communalities are inspected to see if the variables are well defined by the solution. Communalities indicate the percent of variance in a variable that overlaps variance in the factors. 

def evaluate_solution(n_factors, rotation, method, df):
    fa = FactorAnalyzer(n_factors = n_factors, rotation = rotation, method = method)
    fa.fit(df)
    
    #communalities
    communalities = pd.DataFrame(fa.get_communalities(), index = df.columns)
    ft_comm = list(communalities[communalities[0]< 0.3].sort_values(0).index)
    comm_diagnosis = "Total variables with communalities < 0.3 :" + str(len(ft_comm)) 
    
    mean_comm = communalities[0].mean()
    min_comm = communalities[0].min()
    max_comm = communalities[0].max()
    
    des_communalities = "mean = {}, min = {}, max = {})".format(mean_comm, min_comm, max_comm)

    
    #loadings/saturations
    df_loadings = pd.DataFrame(fa.loadings_, columns = ['fa{}'.format(i) for i in range (1, n_factors+1)], index = df.columns)
    df_loadings["highest loading"] = df_loadings.idxmax(axis=1) 
    df_loadings = df_loadings.sort_values("highest loading")
    
    mean_sat = fa.loadings_.mean()
    min_sat = fa.loadings_.min()
    max_sat = fa.loadings_.max()
    
    des_loadings = "mean = {}, min = {}, max = {})".format(mean_sat, min_sat, max_sat)
    
    #interpretabilité des facteurs
    interpretability_diagnosis = ""
    
    if rotation != None:
        for row in df_loadings.T:
            column = df_loadings.T[row]
            column = column[['fa{}'.format(i) for i in range (1, n_factors+1)]].abs() #.sort_values()
            
            # if highest saturation < 0.40, print non-interprétable
            ord_fa = np.sort(column.values)
    
            if ord_fa[-1] < 0.40 :
                interpretability_diagnosis += "Saturation non-interprétable variable " + str(row) + " ; "
    
    # facteurs bien définis : 1-2 saturations élevées (au dessus de .80)            
    factors = ['fa{}'.format(i) for i in range (1, n_factors+1)]
    diagnosis_quality_factors = ""
    
    for factor in factors:
        df_loadings[df_loadings["highest loading"] == factor]
        count = len(df_loadings[df_loadings[factor]> 0.8])
    
        diagnosis_quality_factors += "There are " + str(count) + " factors > 0.8 for " + str(factor) + " ; "
    
    #saturations croisées diagnosis
    count = 0 

    for row in df_loadings.T:
        column = df_loadings.T[row]
        column_names = ['fa{}'.format(i) for i in range (1, n_factors)]
        column = column[column_names].abs() #.sort_values()

        # if second greatest value > 0.35 , 
        ord_fa = np.sort(column.values)
    
        if ord_fa[-2] > 0.35 :
            saturation_diagnosis = "Problème de saturation croisée pour la variable " + str(row)
            count+=1

    if count == 0:
        saturation_diagnosis = "Pas de problème de saturations croisées"
        
    
    #residuals
    if rotation != None:
        factor_correlation_matrix=fa.phi_
        pattern_matrix= fa.loadings_
        pattern_matrix_transpose= np.transpose(fa.loadings_)
        structure_matrix = fa.structure_
        reproduced_correlation_matrix= pattern_matrix.dot((factor_correlation_matrix).dot(pattern_matrix_transpose))
        residuals=fa.corr_ - reproduced_correlation_matrix
        df_residuals=pd.DataFrame(residuals)
        df_residuals_abs = df_residuals.abs()
    
        count_res = 0
        for row in df_residuals_abs:
            for col in df_residuals_abs:
                res = df_residuals_abs[row][col]
                
                if res < 0.05:
                    count_res+=1
                    
        proportion_res = count_res/(df_residuals_abs.shape[0]*df_residuals_abs.shape[1])
        if proportion_res < 0.50:
            residuals_diagnosis= "Pass,  less than 50% are > 0.05. Proportion = {}".format(proportion_res)
        else:
            residuals_diagnosis = "problem, more than 50% are > 0.05. Residuals = {}".formation(proportion_res)
    
    else:
        df_residuals=None
        factor_correlation_matrix = None
        pattern_matrix = fa.loadings_
        structure_matrix = fa.structure_
        reproduced_correlation_matrix = None
        residuals = None
        df_residuals = None
        proportion_res = None
        residuals_diagnosis = None
        
    #variance
    variance = fa.get_factor_variance()
    variance = pd.DataFrame (variance)
    variance.index = ["loadings", "proportion var", "cumulative var"]
    variance.columns = ['fa{}'.format(i) for i in range (1, n_factors+1)]
    
    variance_explained  = variance["fa{}".format(n_factors)]["cumulative var"].max() 
    
    if variance_explained > 0.50:
        variance_diagnosis = "Factors explain more than 50% of common variance"
    
    else :
        variance_diagnosis = "Factors explain less than 50% of common variance"
    
    #eigenvalues
    ev, v = fa.get_eigenvalues()
    df_ev = pd.DataFrame(data = ev).rename(columns = {0: "eigenvalues"})
    df_ev.index = df_ev.index + 1
    
    #uniqueness
    df_uniqueness = pd.DataFrame (fa.get_uniquenesses())
    
    #qualité des facteurs
    count_items_per_factor = pd.DataFrame(df_loadings["highest loading"].value_counts())
    
    return  communalities, ft_comm, comm_diagnosis, des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor

# %%
n_factors = [4, 5, 6]

# %% [markdown]
# #### 6 factors

# %%
communalities, ft_comm, comm_diagnosis,  des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(6, "oblimin", "ml", df_rmv_item2)

to_print = [communalities, ft_comm, comm_diagnosis, des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor]
label_to_print = ["communalities", "index comm < 0.3", "communalities diagnosis", "describe communalities",  "df_loadings", "describe loadings", "interpretability of factors", "quality of factors, items/factor" , "saturation_diagnosis", "factor_correlation_matrix", "pattern_matrix", "structure_matrix", "reproduced_correlation_matrix", "df_residuals", "proportion_residuals_over_0.05", "residuals_diagnosis", "variance", "variance_explained", "variance_diagnosis", "eigenvalues", "df_uniqueness", "count_items_per_factor"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.814410
# MA1012r  0.845987
# MA1023   0.519911
# MA1034r  0.544357
# MA1045   0.502011
# MA1056r  0.567001
# MA1067   0.678156
# MA1078r  0.296462
# MA1089   0.687894
# MA1096r  0.427717
# PH2005   0.546692
# PH2027   0.718967
# PH2049   0.550509
# PH2071   0.230846
# ph2016r  0.477973
# ph2038r  0.617829
# ph2060r  0.436714
# ph2082r  0.638566
# VE1006r  0.487159
# VE1017   0.529706
# VE1028r  0.546862
# VE1039   0.646233
# VE1050r  0.522702
# VE1061   0.722666
# VE1072r  0.272177
# VE1083   0.624862
# MA1023   0.231219  0.015704  0.022777 -0.044350  0.680877 -0.011090
# VE1050r -0.010182  0.045810 -0.043777  0.068601  0.011184  0.716765
# VE1072r -0.131003  0.171841 -0.097439  0.112966  0.198545  0.404735
# VE1028r  0.001882  0.021001  0.025709  0.134184 -0.040961  0.725309
#
#         highest loading
# MA1001              fa1
# MA1012r             fa1
# MA1034r             fa1
# MA1056r             fa1
# MA1067              fa1
# MA1089              fa1
# SS1009              fa1
# ss1064r             fa2
# ss1042r             fa2
# ss1020r             fa2
# SS1094              fa2
# SS1075              fa2
# SS1053              fa2
# ss1086r             fa2
# ss1101r             fa2
# ph2038r             fa3
# PH2005              fa3
# PH2027              fa3
# PH2049              fa3
# ph2016r             fa3
# ph2082r             fa3
# PH2071              fa3
# ph2060r             fa3
# VE1039              fa4
# VE1061              fa4
# VE1017              fa4
# VE1099              fa4
# VE1006r             fa4
# VE1083              fa4
# MA1096r             fa5
# MA1078r             fa5
# MA1045              fa5
# MA1023              fa5
# VE1050r             fa6
# VE1072r             fa6
# VE1028r             fa6
#
#
# describe loadings
#
#
# mean = 0.14044337798953604, min = -0.22032223222112807, max = 0.9119672639718273)
#
#
# interpretability of factors
#
#
# Saturation non-interprétable variable SS1009 ;
#
#
# quality of factors, items/factor
#
#
# There are 4 factors > 0.8 for fa1 ; There are 3 factors > 0.8 for fa2 ; There are 1 factors > 0.8 for fa3 ; There are 1 factors > 0.8 for fa4 ; There are 0 factors > 0.8 for fa5 ; There are 0 factors > 0.8 for fa6 ;
#
#
# saturation_diagnosis
#
#
# Problème de saturation croisée pour la variable MA1096r
#
#
# factor_correlation_matrix
#
#
# [[ 1.          0.01922797  0.12890464  0.56355326  0.50807078  0.02828734]
#  [ 0.01922797  1.         -0.01047383  0.45444921  0.09220221  0.49856272]
#  [ 0.12890464 -0.01047383  1.          0.11369629  0.12242883 -0.0906001 ]
#  [ 0.56355326  0.45444921  0.11369629  1.          0.29562114  0.37665757]
#  [ 0.50807078  0.09220221  0.12242883  0.29562114  1.         -0.02583734]
#  [ 0.02828734  0.49856272 -0.0906001   0.37665757 -0.02583734  1.        ]]
#
#
# pattern_matrix
#
#
# [[ 0.8899603  -0.09291184  0.00291179  0.00606902  0.10894067 -0.04283788]
#  [ 0.91196726  0.0323612   0.00554712 -0.06648745 -0.0727377   0.05926961]
#  [ 0.23121911  0.01570439  0.02277748 -0.04434972  0.6808767  -0.01109049]
#  [ 0.72056373  0.10025214  0.03073424 -0.06250093  0.09796467  0.02542378]
#  [-0.03781145  0.0621125   0.04327082  0.02500977  0.6998516  -0.06658346]
#  [ 0.71798557  0.2022863  -0.05220093 -0.0746475   0.04760922 -0.00378757]
#  [ 0.81722223  0.07611812  0.01252834  0.03975058  0.05034098 -0.01545949]
#  [ 0.29398224  0.0489244   0.01726608 -0.05462421  0.44569406  0.07561237]
#  [ 0.81893106 -0.00173421  0.02602465  0.10963683  0.0487339  -0.04658937]
#  [ 0.36266574  0.04790682  0.03190711 -0.08315208  0.51870928  0.13001634]
# 4   0.090114
# 5   0.285001
# 6   0.303885
# 7   0.176570
# 8   0.312435
# 9   0.202653
# 10  0.052935
# 11  0.076640
# 12  0.064467
# 13  0.068494
# 14  0.037396
# 15  0.062767
# 16  0.072212
# 17  0.063320
# 18 -0.120510
# 19 -0.068473
# 20 -0.060390
# 21 -0.073257
# 22 -0.079934
# 23 -0.075628
# 24 -0.063379
# 25 -0.013102
# 26 -0.017830
# 27  0.135172
# 28  0.155630
# 29  0.057333
# 30  0.124401
# 31  0.120798
# 32  0.023706
# 33  0.036039
# 34  0.055938
# 35  0.418343
#
#
# proportion_residuals_over_0.05
#
#
# 0.3888888888888889
#
#
# residuals_diagnosis
#
#
# Pass,  less than 50% are > 0.05. Proportion = 0.3888888888888889
#
#
# variance
#
#
#                      fa1       fa2       fa3       fa4       fa5       fa6
# loadings        4.624007  4.204416  4.033017  3.681812  1.684875  1.353250
# proportion var  0.128445  0.116789  0.112028  0.102273  0.046802  0.037590
# cumulative var  0.128445  0.245234  0.357262  0.459535  0.506337  0.543927
#
#
# variance_explained
#
#
# 0.5439271590806604
#
#
# variance_diagnosis
#
#
# Factors explain more than 50% of common variance
#
#
# eigenvalues
#
#
#     eigenvalues
# 1     11.138797
# 2      5.522202
# 3      4.089780
# 4      1.653834
# 5      1.151814
# 6      1.048644
# 7      0.890933
# 8      0.785026
# 9      0.699901
# 10     0.612056
# 11     0.557549
# 12     0.534713
# 13     0.493285
# 14     0.489553
# 15     0.465200
# 16     0.443668
# 17     0.434225
# 18     0.398563
# 19     0.389121
# 20     0.360514
# 21     0.340516
# 22     0.331948
# 23     0.312983
# 24     0.299779
# 25     0.290045
# 26     0.270185
# 27     0.248128
# 28     0.241363
# 29     0.233153
# 30     0.216358
# 31     0.209546
# 32     0.187827
# 33     0.180213
# 34     0.174298
# 35     0.170578
# 36     0.133706
#
#
# df_uniqueness
#
#
#            0
# 0   0.185590
# 1   0.154013
# 2   0.480089
# 3   0.455643
# 4   0.497989
# 5   0.432999
# 6   0.321844
# 7   0.703538
# 8   0.312106
# 9   0.572283
# 10  0.453308
# 11  0.281033
# 12  0.449491
# 13  0.769154
# 14  0.522027
# 15  0.382171
# 16  0.563286
# 17  0.361434
# 18  0.512841
# 19  0.470294
# 20  0.453138
# 21  0.353767
# 22  0.477298
# 23  0.277334
# 24  0.727823
# 25  0.375138
# 26  0.379645
# 27  0.808474
# 28  0.670580
# 29  0.470542
# 30  0.567773
# 31  0.613318
# 32  0.316374
# 33  0.214456
# 34  0.335307
# 35  0.496524
#
#
# count_items_per_factor
#
#
#      highest loading
# fa2                8
# fa3                8
# fa1                7
# fa4                6
# fa5                4
# fa6                3

# %% [markdown]
# > Voir différence avec la qualité de la représentation initiale

# %%
# qualité repr initiale - qualité après extraction
diff_communality_6 = 0.6103910391235944 - 0.5439271590806602 #0.6214422425288526
diff_communality_6
# Out:
# 0.06646388004293413

# %% [markdown]
# #### 5 factors

# %%
communalities, ft_comm, comm_diagnosis, des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(5, "oblimin", "ml", df_rmv_item2)

to_print = [communalities, ft_comm, comm_diagnosis, des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor]
label_to_print = ["communalities", "ind < 0.3 communalities", "communalities diagnosis", "describe communalities",  "df_loadings", "describe loadings", "interpretability of factors", "quality of factors, items/factor" , "saturation_diagnosis", "factor_correlation_matrix", "pattern_matrix", "structure_matrix", "reproduced_correlation_matrix", "df_residuals", "proportion_residuals_over_0.05", "residuals_diagnosis", "variance", "variance_explained", "variance_diagnosis", "eigenvalues", "df_uniqueness", "count_items_per_factor"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.832348
# MA1012r  0.829777
# MA1023   0.524437
# MA1034r  0.543214
# MA1045   0.507551
# MA1056r  0.575311
# MA1067   0.692363
# MA1078r  0.273704
# MA1089   0.701654
# MA1096r  0.377059
# PH2005   0.545785
# PH2027   0.721951
# PH2049   0.559223
# PH2071   0.229013
# ph2016r  0.482839
# ph2038r  0.601125
# ph2060r  0.435163
# ph2082r  0.635951
# VE1006r  0.565844
# VE1017   0.522642
# VE1028r  0.276875
# VE1039   0.755992
# VE1050r  0.237030
# VE1061   0.793462
# VE1072r  0.234698
# VE1083   0.652148
# VE1099   0.641738
# SS1009   0.185301
# SS1053   0.313677
# SS1075   0.443265
# SS1094   0.378717
# ss1020r  0.417765
# ss1042r  0.707662
# ss1064r  0.815094
# ss1086r  0.664149
# ss1101r  0.535568
#
#
# ind < 0.3 communalities
#
#
# ['SS1009', 'PH2071', 'VE1072r', 'VE1050r', 'MA1078r', 'VE1028r']
#
#
# communalities diagnosis
#
#
# Total variables with communalities < 0.3 :6
#
#
# describe communalities
#
#
# mean = 0.5336137606381498, min = 0.1853014603910281, max = 0.8323482385025885)
#
#
# df_loadings
#
#
#               fa1       fa2       fa3       fa4       fa5 highest loading
# MA1001   0.899464 -0.108920 -0.010615  0.005445  0.106336             fa1
# MA1012r  0.904846  0.052518 -0.040029 -0.002636 -0.081637             fa1
# MA1034r  0.720359  0.112383 -0.054077  0.025449  0.089974             fa1
# MA1056r  0.723290  0.202903 -0.079756 -0.053005  0.042691             fa1
# MA1067   0.827428  0.065141  0.034705  0.014282  0.045553             fa1
# MA1089   0.830097 -0.024731  0.091970  0.031718  0.050167             fa1
# SS1009   0.281681  0.157280  0.205458  0.017431  0.196731             fa1
# ss1064r -0.038453  0.901463 -0.018956  0.000884  0.024897             fa2
# ss1042r -0.034480  0.837905  0.009121  0.007020  0.065233             fa2
# ss1020r  0.129945  0.628033  0.073670  0.031733 -0.004531             fa2
# SS1094   0.238890  0.506143  0.254165 -0.005144  0.029007             fa2
# SS1075   0.163552  0.625250  0.154997 -0.030192  0.025355             fa2
# SS1053   0.295990  0.432451  0.196121  0.023495  0.006109             fa2
# ss1086r  0.016834  0.813862  0.034200  0.017998 -0.000573             fa2
# ss1101r  0.121881  0.718255  0.035517  0.059391  0.005846             fa2
# VE1083   0.064478  0.133285  0.791196  0.012855 -0.063788             fa3
# VE1006r -0.012951  0.013487  0.748705 -0.054799 -0.043953             fa3
# VE1017  -0.212321 -0.001755  0.590964 -0.026907  0.357206             fa3
# VE1028r -0.070595  0.240942  0.448057 -0.050086 -0.102830             fa3
# VE1039   0.043602 -0.018189  0.866745  0.017268 -0.047071             fa3
# VE1050r -0.073057  0.259474  0.383769 -0.115734 -0.060768             fa3
# VE1061  -0.048769 -0.079843  0.884761  0.023310  0.036924             fa3
# VE1072r -0.156229  0.289329  0.292426 -0.137208  0.149133             fa3
# VE1099   0.032377  0.140375  0.787244  0.029277 -0.019364             fa3
# PH2005  -0.034329 -0.052092  0.073323  0.731607  0.035613             fa4
# PH2027   0.004027 -0.105322  0.078819  0.839012  0.026241             fa4
# PH2049   0.086639 -0.121809  0.084193  0.727677  0.016620             fa4
# ph2038r  0.044759 -0.001536 -0.041089  0.764634 -0.112986             fa4
# PH2071   0.044984  0.029773  0.029343  0.465480  0.092577             fa4
# ph2060r -0.025957  0.173516 -0.097379  0.628171  0.017322             fa4
# ph2016r -0.082058  0.193205 -0.108137  0.652517  0.036126             fa4
# ph2082r -0.038163  0.110046 -0.059147  0.786664  0.006775             fa4
# MA1096r  0.357431  0.100125 -0.031345  0.013002  0.487981             fa5
# MA1078r  0.292380  0.082040 -0.025851  0.004818  0.425201             fa5
# MA1045  -0.030386  0.051133 -0.014783  0.046245  0.708276             fa5
# MA1023   0.229192  0.027716 -0.060941  0.017291  0.683467             fa5
#
#
# describe loadings
#
#
# mean = 0.16186887613798057, min = -0.21232098459019266, max = 0.9048455125876195)
#
#
# interpretability of factors
#
#
# Saturation non-interprétable variable SS1009 ; Saturation non-interprétable variable VE1050r ; Saturation non-interprétable variable VE1072r ;
#
#
# quality of factors, items/factor
#
#
# There are 4 factors > 0.8 for fa1 ; There are 3 factors > 0.8 for fa2 ; There are 2 factors > 0.8 for fa3 ; There are 1 factors > 0.8 for fa4 ; There are 0 factors > 0.8 for fa5 ;
#
#
# saturation_diagnosis
#
#
# Pas de problème de saturations croisées
#
#
# factor_correlation_matrix
#
#
# [[ 1.          0.01972189  0.13094338  0.55263331  0.50488719]
#  [ 0.01972189  1.         -0.02548606  0.48672307  0.08379971]
#  [ 0.13094338 -0.02548606  1.          0.10287443  0.13020251]
#  [ 0.55263331  0.48672307  0.10287443  1.          0.2756871 ]
#  [ 0.50488719  0.08379971  0.13020251  0.2756871   1.        ]]
#
#
# pattern_matrix
#
#
# [[ 8.99463794e-01 -1.08919859e-01 -1.06152130e-02  5.44516809e-03
#    1.06335574e-01]
#  [ 9.04845513e-01  5.25177780e-02 -4.00285566e-02 -2.63569254e-03
#   -8.16371369e-02]
#  [ 2.29192010e-01  2.77159265e-02 -6.09412491e-02  1.72906118e-02
#    6.83466867e-01]
#  [ 7.20358797e-01  1.12382573e-01 -5.40771355e-02  2.54490207e-02
#    8.99741038e-02]
#  [-3.03860774e-02  5.11327122e-02 -1.47826033e-02  4.62447803e-02
#    7.08276491e-01]
#  [ 7.23289856e-01  2.02902692e-01 -7.97555507e-02 -5.30046200e-02
#    4.26913863e-02]
#  [ 8.27427617e-01  6.51409500e-02  3.47048616e-02  1.42821210e-02
#    4.55527279e-02]
#  [ 2.92380234e-01  8.20403457e-02 -2.58512369e-02  4.81795988e-03
# 33  0.200655  0.132988  0.183856  0.073997 -0.008051  0.181793  0.011639
# 34  0.188556  0.168860  0.229894  0.097713  0.010310  0.011639  0.321957
# 35  0.220352  0.129924  0.226780  0.139980  0.026635  0.027752  0.062764
#
#           35
# 0   0.303146
# 1   0.311049
# 2   0.154150
# 3   0.277696
# 4   0.055409
# 5   0.258034
# 6   0.294983
# 7   0.156239
# 8   0.318483
# 9   0.177539
# 10 -0.221516
# 11 -0.241218
# 12 -0.208490
# 13 -0.119959
# 14 -0.282734
# 15 -0.271395
# 16 -0.230148
# 17 -0.288502
# 18  0.216926
# 19  0.185226
# 20  0.185718
# 21  0.284266
# 22  0.167908
# 23  0.282951
# 24  0.137912
# 25  0.308165
# 26  0.295583
# 27  0.202942
# 28  0.220352
# 29  0.129924
# 30  0.226780
# 31  0.139980
# 32  0.026635
# 33  0.027752
# 34  0.062764
# 35  0.409517
#
#
# proportion_residuals_over_0.05
#
#
# 0.22530864197530864
#
#
# residuals_diagnosis
#
#
# Pass,  less than 50% are > 0.05. Proportion = 0.22530864197530864
#
#
# variance
#
#
#                      fa1       fa2       fa3       fa4       fa5
# loadings        4.706755  4.402221  4.372887  4.063614  1.664619
# proportion var  0.130743  0.122284  0.121469  0.112878  0.046239
# cumulative var  0.130743  0.253027  0.374496  0.487374  0.533614
#
#
# variance_explained
#
#
# 0.5336137606381498
#
#
# variance_diagnosis
#
#
# Factors explain more than 50% of common variance
#
#
# eigenvalues
#
#
#     eigenvalues
# 1     11.138797
# 2      5.522202
# 3      4.089780
# 4      1.653834
# 5      1.151814
# 6      1.048644
# 7      0.890933
# 8      0.785026
# 9      0.699901
# 10     0.612056
# 11     0.557549
# 12     0.534713
# 13     0.493285
# 14     0.489553
# 15     0.465200
# 16     0.443668
# 17     0.434225
# 18     0.398563
# 19     0.389121
# 20     0.360514
# 21     0.340516
# 22     0.331948
# 23     0.312983
# 24     0.299779
# 25     0.290045
# 26     0.270185
# 27     0.248128
# 28     0.241363
# 29     0.233153
# 30     0.216358
# 31     0.209546
# 32     0.187827
# 33     0.180213
# 34     0.174298
# 35     0.170578
# 36     0.133706
#
#
# df_uniqueness
#
#
#            0
# 0   0.167652
# 1   0.170223
# 2   0.475563
# 3   0.456786
# 4   0.492449
# 5   0.424689
# 6   0.307637
# 7   0.726296
# 8   0.298346
# 9   0.622941
# 10  0.454215
# 11  0.278049
# 12  0.440777
# 13  0.770987
# 14  0.517161
# 15  0.398875
# 16  0.564837
# 17  0.364049
# 18  0.434156
# 19  0.477358
# 20  0.723125
# 21  0.244008
# 22  0.762970
# 23  0.206538
# 24  0.765302
# 25  0.347852
# 26  0.358262
# 27  0.814699
# 28  0.686323
# 29  0.556735
# 30  0.621283
# 31  0.582235
# 32  0.292338
# 33  0.184906
# 34  0.335851
# 35  0.464432
#
#
# count_items_per_factor
#
#
#      highest loading
# fa3                9
# fa2                8
# fa4                8
# fa1                7
# fa5                4

# %%
diff_communalities_5 = 0.6103910391235944 - 0.5336137606381498
diff_communalities_5
# Out:
# 0.07677727848544458

# %% [markdown]
# #### 4 factors

# %%
communalities, ft_comm, comm_diagnosis, des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(4, "oblimin", "ml", df_rmv_item2)

to_print = [communalities, ft_comm, comm_diagnosis, des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor]
label_to_print = ["communalities", "index <0.3 communalities", "communalities diagnosis", "describe communalities",  "df_loadings", "describe loadings", "interpretability of factors", "quality of factors, items/factor" , "saturation_diagnosis", "factor_correlation_matrix", "pattern_matrix", "structure_matrix", "reproduced_correlation_matrix", "df_residuals", "proportion_residuals_over_0.05", "residuals_diagnosis", "variance", "variance_explained", "variance_diagnosis", "eigenvalues", "df_uniqueness", "count_items_per_factor"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.928800
# MA1012r  0.676275
# MA1023   0.530259
# MA1034r  0.608510
# MA1045   0.282327
# MA1056r  0.606980
# MA1067   0.711862
# MA1078r  0.370211
# MA1089   0.714728
# MA1096r  0.506075
# PH2005   0.548828
# PH2027   0.722757
# PH2049   0.554225
# PH2071   0.234901
# ph2016r  0.480037
# ph2038r  0.576021
# ph2060r  0.436664
# ph2082r  0.638901
# VE1006r  0.556043
# VE1017   0.450305
# VE1028r  0.287317
# VE1039   0.724293
# VE1050r  0.247959
# VE1061   0.806635
# VE1072r  0.186459
# VE1083   0.621774
# VE1099   0.632031
# SS1009   0.244611
# SS1053   0.315085
# SS1075   0.444425
# SS1094   0.384390
# ss1020r  0.423636
# ss1042r  0.660546
# ss1064r  0.789140
# ss1086r  0.657732
# ss1101r  0.541949
#
#
# index <0.3 communalities
#
#
# ['VE1072r', 'PH2071', 'SS1009', 'VE1050r', 'MA1045', 'VE1028r']
#
#
# communalities diagnosis
#
#
# Total variables with communalities < 0.3 :6
#
#
# describe communalities
#
#
# mean = 0.5306302362444398, min = 0.18645871626947982, max = 0.9287995134699805)
#
#
# df_loadings
#
#
#               fa1       fa2       fa3       fa4 highest loading
# MA1001   0.957718 -0.033107 -0.101917 -0.009674             fa1
# MA1096r  0.708598  0.048620 -0.012476  0.037998             fa1
# MA1078r  0.605504  0.047948 -0.022940  0.027397             fa1
# MA1067   0.839267  0.004242  0.086428 -0.002182             fa1
# MA1056r  0.737947 -0.103483  0.217807 -0.065311             fa1
# MA1089   0.843112  0.060582 -0.001978  0.014722             fa1
# MA1034r  0.767609 -0.070657  0.118583  0.015242             fa1
# MA1023   0.713683  0.052600 -0.122057  0.057017             fa1
# MA1012r  0.806592 -0.102668  0.119850 -0.027928             fa1
# MA1045   0.493706  0.119113 -0.126321  0.091848             fa1
# SS1009   0.420379  0.232184  0.115765  0.024123             fa1
# VE1006r -0.052968  0.740823  0.026434 -0.060995             fa2
# VE1061  -0.026358  0.893007 -0.089424  0.021955             fa2
# VE1050r -0.125860  0.376464  0.276450 -0.118187             fa2
# VE1039  -0.005106  0.850990  0.003976  0.008258             fa2
# VE1028r -0.157956  0.430681  0.271685 -0.055388             fa2
# VE1017   0.053619  0.661957 -0.096134 -0.001123             fa2
# VE1083   0.004012  0.772339  0.158854  0.003903             fa2
# VE1072r -0.043193  0.333772  0.241276 -0.122372             fa2
# VE1099   0.006700  0.779825  0.152610  0.023880             fa2
# SS1053   0.288303  0.185017  0.444289  0.018505             fa3
# SS1075   0.176610  0.157654  0.622513 -0.029272             fa3
# SS1094   0.251667  0.252108  0.507392 -0.007031             fa3
# ss1042r  0.016133  0.032829  0.811718  0.017955             fa3
# ss1064r -0.020460 -0.003484  0.888038  0.009858             fa3
# ss1020r  0.118651  0.069671  0.635354  0.032077             fa3
# ss1101r  0.117653  0.034383  0.723278  0.061595             fa3
# ss1086r  0.016375  0.041195  0.809480  0.022568             fa3
# ph2060r -0.012447 -0.095320  0.170207  0.631231             fa4
# ph2038r -0.047465 -0.073584  0.040391  0.752809             fa4
# ph2016r -0.053845 -0.100795  0.184274  0.658043             fa4
# PH2071   0.111167  0.041510  0.011377  0.469777             fa4
# PH2049   0.096843  0.076862 -0.118074  0.724567             fa4
# PH2027   0.022753  0.077437 -0.107243  0.839489             fa4
# PH2005  -0.006260  0.077010 -0.060065  0.734337             fa4
# ph2082r -0.032397 -0.060774  0.110568  0.788627             fa4
#
#
# describe loadings
#
#
# mean = 0.19358000243541276, min = -0.15795634465465197, max = 0.9577175076603629)
#
#
# interpretability of factors
#
#
# Saturation non-interprétable variable VE1050r ; Saturation non-interprétable variable VE1072r ;
#
#
# quality of factors, items/factor
#
#
# There are 4 factors > 0.8 for fa1 ; There are 2 factors > 0.8 for fa2 ; There are 3 factors > 0.8 for fa3 ; There are 1 factors > 0.8 for fa4 ;
#
#
# saturation_diagnosis
#
#
# Pas de problème de saturations croisées
#
#
# factor_correlation_matrix
#
#
# [[ 1.          0.05444457  0.14884012  0.55965999]
#  [ 0.05444457  1.         -0.01546223  0.48333281]
#  [ 0.14884012 -0.01546223  1.          0.09579719]
#  [ 0.55965999  0.48333281  0.09579719  1.        ]]
#
#
# pattern_matrix
#
#
# [[ 0.95771751 -0.03310652 -0.10191696 -0.00967368]
#  [ 0.8065921  -0.10266786  0.11984951 -0.0279285 ]
#  [ 0.71368306  0.05260037 -0.12205711  0.05701706]
#  [ 0.76760861 -0.0706567   0.11858338  0.01524202]
#  [ 0.49370601  0.11911274 -0.12632149  0.09184752]
#  [ 0.73794698 -0.10348253  0.21780681 -0.06531091]
#  [ 0.83926743  0.00424163  0.086428   -0.00218234]
#  [ 0.60550426  0.04794756 -0.02294046  0.02739703]
#  [ 0.84311152  0.06058197 -0.001978    0.01472229]
#  [ 0.70859849  0.04862044 -0.01247575  0.0379985 ]
#  [-0.00626013  0.07701003 -0.06006492  0.73433656]
#  [ 0.02275271  0.07743749 -0.10724335  0.83948863]
#  [ 0.09684319  0.07686164 -0.11807363  0.72456707]
#  [ 0.11116727  0.04150965  0.01137698  0.46977699]
#  [-0.05384547 -0.10079471  0.18427351  0.65804325]
#  [-0.04746471 -0.07358369  0.0403909   0.75280922]
#  [-0.01244748 -0.09532007  0.1702068   0.63123084]
#  [-0.03239741 -0.06077355  0.11056845  0.7886268 ]
#  [-0.0529684   0.74082256  0.02643381 -0.06099464]
#  [ 0.05361878  0.66195683 -0.09613362 -0.00112338]
#  [-0.15795634  0.43068071  0.27168543 -0.05538793]
# 16 -0.130150 -0.145178 -0.136009 -0.088111 -0.054097 -0.032303 -0.067745
# 17 -0.164256 -0.124740 -0.166771 -0.083489 -0.060206 -0.028985 -0.066849
# 18  0.126303  0.220148  0.183795  0.215720  0.297253  0.313191  0.312715
# 19  0.125388  0.212372  0.157709  0.219378  0.295817  0.326967  0.278616
# 20  0.083926  0.077748  0.125731  0.150282  0.127923  0.109919  0.108677
# 21  0.199944  0.288312  0.214539  0.240796  0.336369  0.356063  0.328652
# 22  0.138506  0.100624  0.115880  0.147873  0.120250  0.102432  0.103917
# 23  0.128155  0.243802  0.190408  0.247801  0.333732  0.397899  0.363844
# 24  0.171074  0.145634  0.143897  0.119286  0.127029  0.135131  0.087726
# 25  0.170194  0.265201  0.227715  0.267281  0.325973  0.350038  0.274457
# 26  0.250095  0.284914  0.244596  0.238330  0.278008  0.339819  0.309697
# 27  0.231707  0.207221  0.162706  0.159863  0.234757  0.269832  0.216052
# 28  0.632663  0.246123  0.214949  0.153661  0.157648  0.163960  0.156906
# 29  0.246123  0.536589  0.342416  0.109850  0.153311  0.111152  0.146738
# 30  0.214949  0.342416  0.579023  0.150938  0.194327  0.152860  0.201696
# 31  0.153661  0.109850  0.150938  0.544067  0.073635  0.071618  0.092737
# 32  0.157648  0.153311  0.194327  0.073635  0.332636  0.035144  0.039829
# 33  0.163960  0.111152  0.152860  0.071618  0.035144  0.214747  0.032645
# 34  0.156906  0.146738  0.201696  0.092737  0.039829  0.032645  0.334467
# 35  0.194754  0.108806  0.202211  0.134861  0.046034  0.040503  0.069846
#
#           35
# 0   0.227760
# 1   0.206652
# 2   0.211839
# 3   0.224084
# 4   0.153670
# 5   0.179775
# 6   0.220965
# 7   0.183748
# 8   0.246991
# 9   0.206040
# 10 -0.020813
# 11 -0.017917
# 12 -0.024548
# 13  0.009123
# 14 -0.094999
# 15 -0.088789
# 16 -0.056292
# 17 -0.073966
# 18  0.184964
# 19  0.228855
# 20  0.157158
# 21  0.260442
# 22  0.129519
# 23  0.282584
# 24  0.132440
# 25  0.281518
# 26  0.282182
# 27  0.201023
# 28  0.194754
# 29  0.108806
# 30  0.202211
# 31  0.134861
# 32  0.046034
# 33  0.040503
# 34  0.069846
# 35  0.414353
#
#
# proportion_residuals_over_0.05
#
#
# 0.1574074074074074
#
#
# residuals_diagnosis
#
#
# Pass,  less than 50% are > 0.05. Proportion = 0.1574074074074074
#
#
# variance
#
#
#                      fa1       fa2       fa3       fa4
# loadings        6.199647  4.437830  4.391480  4.073731
# proportion var  0.172212  0.123273  0.121986  0.113159
# cumulative var  0.172212  0.295485  0.417471  0.530630
#
#
# variance_explained
#
#
# 0.5306302362444398
#
#
# variance_diagnosis
#
#
# Factors explain more than 50% of common variance
#
#
# eigenvalues
#
#
#     eigenvalues
# 1     11.138797
# 2      5.522202
# 3      4.089780
# 4      1.653834
# 5      1.151814
# 6      1.048644
# 7      0.890933
# 8      0.785026
# 9      0.699901
# 10     0.612056
# 11     0.557549
# 12     0.534713
# 13     0.493285
# 14     0.489553
# 15     0.465200
# 16     0.443668
# 17     0.434225
# 18     0.398563
# 19     0.389121
# 20     0.360514
# 21     0.340516
# 22     0.331948
# 23     0.312983
# 24     0.299779
# 25     0.290045
# 26     0.270185
# 27     0.248128
# 28     0.241363
# 29     0.233153
# 30     0.216358
# 31     0.209546
# 32     0.187827
# 33     0.180213
# 34     0.174298
# 35     0.170578
# 36     0.133706
#
#
# df_uniqueness
#
#
#            0
# 0   0.071200
# 1   0.323725
# 2   0.469741
# 3   0.391490
# 4   0.717673
# 5   0.393020
# 6   0.288138
# 7   0.629789
# 8   0.285272
# 9   0.493925
# 10  0.451172
# 11  0.277243
# 12  0.445775
# 13  0.765099
# 14  0.519963
# 15  0.423979
# 16  0.563336
# 17  0.361099
# 18  0.443957
# 19  0.549695
# 20  0.712683
# 21  0.275707
# 22  0.752041
# 23  0.193365
# 24  0.813541
# 25  0.378226
# 26  0.367969
# 27  0.755389
# 28  0.684915
# 29  0.555575
# 30  0.615610
# 31  0.576364
# 32  0.339454
# 33  0.210860
# 34  0.342268
# 35  0.458051
#
#
# count_items_per_factor
#
#
#      highest loading
# fa1               11
# fa2                9
# fa3                8
# fa4                8

# %%
diff_communalities = 0.6103910391235944 - 0.5306302362444398 #0.5722324166216669

diff_communalities
# Out:
# 0.07976080287915455

# %% [markdown]
# > Nous sélectionnons la solution avec 4 items comme elle est concordante avec les dimensions du questionnaire. Globalement, les solutions sont pas mal semblables, mais les facteurs sont mieux définis et interprétables pour un n facteur = 4.
#
# > Nous pouvons voir que d'entre les variables 6 ont une faible qualité de représentation (< 0.30) Nous allons donc les retirer une à une, itérativement , et recalculer le kmo, déterminant et résultat au test de Barlett.

# %% [markdown]
# ### Retrait d'items avec faible représentation après extraction

# %% [markdown]
# *item 1*

# %%
# remove items with communalities < 0.3 et si >= 1 (cas Heywood)

rmv_item = [*range(0,len(ft_comm), 1)]
df_rmv_third_item = df_rmv_item2.drop(columns = ft_comm[rmv_item[0]])

communalities, ft_comm, comm_diagnosis,  des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(4, "oblimin", "ml", df_rmv_third_item)

to_print = [communalities, ft_comm]
label_to_print = ["communalities", "index <0.3 communalities"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.928206
# MA1012r  0.675242
# MA1023   0.533116
# MA1034r  0.607634
# MA1045   0.283968
# MA1056r  0.605655
# MA1067   0.710973
# MA1078r  0.371777
# MA1089   0.714425
# MA1096r  0.507853
# PH2005   0.549619
# PH2027   0.723264
# PH2049   0.553196
# PH2071   0.233869
# ph2016r  0.478902
# ph2038r  0.575412
# ph2060r  0.436747
# ph2082r  0.639984
# VE1006r  0.555670
# VE1017   0.448790
# VE1028r  0.283050
# VE1039   0.723615
# VE1050r  0.241623
# VE1061   0.804880
# VE1083   0.624181
# VE1099   0.631542
# SS1009   0.243841
# SS1053   0.314644
# SS1075   0.446369
# SS1094   0.385609
# ss1020r  0.424589
# ss1042r  0.662631
# ss1064r  0.791033
# ss1086r  0.663130
# ss1101r  0.542609
#
#
# index <0.3 communalities
#
#
# ['PH2071', 'VE1050r', 'SS1009', 'VE1028r', 'MA1045']

# %% [markdown]
# *Item 2*

# %%
rmv_item = [*range(0,len(ft_comm), 1)]
df_rmv_fourth_item = df_rmv_third_item.drop(columns = ft_comm[rmv_item[0]])

communalities, ft_comm, comm_diagnosis,  des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(4, "oblimin", "ml", df_rmv_fourth_item)

to_print = [communalities, ft_comm]
label_to_print = ["communalities", "index <0.3 communalities"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.929761
# MA1012r  0.675203
# MA1023   0.532610
# MA1034r  0.607439
# MA1045   0.282443
# MA1056r  0.604977
# MA1067   0.711209
# MA1078r  0.372717
# MA1089   0.715656
# MA1096r  0.508605
# PH2005   0.563283
# PH2027   0.729071
# PH2049   0.533592
# ph2016r  0.461983
# ph2038r  0.574511
# ph2060r  0.432596
# ph2082r  0.651634
# VE1006r  0.555835
# VE1017   0.448687
# VE1028r  0.282858
# VE1039   0.723247
# VE1050r  0.240768
# VE1061   0.805105
# VE1083   0.624336
# VE1099   0.631463
# SS1009   0.244324
# SS1053   0.314852
# SS1075   0.446423
# SS1094   0.385738
# ss1020r  0.423615
# ss1042r  0.663533
# ss1064r  0.792359
# ss1086r  0.663790
# ss1101r  0.542805
#
#
# index <0.3 communalities
#
#
# ['VE1050r', 'SS1009', 'MA1045', 'VE1028r']

# %% [markdown]
# *Item 3*

# %%
rmv_item = [*range(0,len(ft_comm), 1)]
df_rmv_fifth_item = df_rmv_fourth_item.drop(columns = ft_comm[rmv_item[0]])

communalities, ft_comm, comm_diagnosis,  des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(4, "oblimin", "ml", df_rmv_fifth_item)

to_print = [communalities, ft_comm]
label_to_print = ["communalities", "index <0.3 communalities"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.933174
# MA1012r  0.676799
# MA1023   0.533300
# MA1034r  0.607392
# MA1045   0.282531
# MA1056r  0.603973
# MA1067   0.711591
# MA1078r  0.373049
# MA1089   0.715907
# MA1096r  0.511045
# PH2005   0.563702
# PH2027   0.729982
# PH2049   0.533725
# ph2016r  0.460772
# ph2038r  0.575705
# ph2060r  0.431691
# ph2082r  0.650758
# VE1006r  0.554078
# VE1017   0.448279
# VE1028r  0.269664
# VE1039   0.715546
# VE1061   0.802519
# VE1083   0.626008
# VE1099   0.633525
# SS1009   0.242413
# SS1053   0.314659
# SS1075   0.451566
# SS1094   0.388020
# ss1020r  0.423433
# ss1042r  0.668373
# ss1064r  0.799581
# ss1086r  0.670329
# ss1101r  0.543584
#
#
# index <0.3 communalities
#
#
# ['SS1009', 'VE1028r', 'MA1045']

# %% [markdown]
# *Item 4*

# %%
rmv_item = [*range(0,len(ft_comm), 1)]
df_rmv_sixth_item = df_rmv_fifth_item.drop(columns = ft_comm[rmv_item[0]])

communalities, ft_comm, comm_diagnosis,  des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(4, "oblimin", "ml", df_rmv_sixth_item)

to_print = [communalities, ft_comm]
label_to_print = ["communalities", "index <0.3 communalities"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.933378
# MA1012r  0.676087
# MA1023   0.523629
# MA1034r  0.609257
# MA1045   0.273679
# MA1056r  0.602738
# MA1067   0.715834
# MA1078r  0.371942
# MA1089   0.717568
# MA1096r  0.508651
# PH2005   0.562759
# PH2027   0.729933
# PH2049   0.534830
# ph2016r  0.459738
# ph2038r  0.575099
# ph2060r  0.431510
# ph2082r  0.650689
# VE1006r  0.556571
# VE1017   0.443261
# VE1028r  0.268609
# VE1039   0.713634
# VE1061   0.805003
# VE1083   0.629609
# VE1099   0.632941
# SS1053   0.314543
# SS1075   0.452406
# SS1094   0.388587
# ss1020r  0.422743
# ss1042r  0.670261
# ss1064r  0.802334
# ss1086r  0.670352
# ss1101r  0.544310
#
#
# index <0.3 communalities
#
#
# ['VE1028r', 'MA1045']

# %% [markdown]
# *Item 5*

# %%
rmv_item = [*range(0,len(ft_comm), 1)]
df_rmv_seventh_item = df_rmv_sixth_item.drop(columns = ft_comm[rmv_item[0]])

communalities, ft_comm, comm_diagnosis,  des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(4, "oblimin", "ml", df_rmv_seventh_item)

to_print = [communalities, ft_comm]
label_to_print = ["communalities", "index <0.3 communalities"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.936151
# MA1012r  0.679888
# MA1023   0.525365
# MA1034r  0.611415
# MA1045   0.272232
# MA1056r  0.602337
# MA1067   0.715740
# MA1078r  0.373345
# MA1089   0.717928
# MA1096r  0.511379
# PH2005   0.562598
# PH2027   0.729864
# PH2049   0.534776
# ph2016r  0.459110
# ph2038r  0.575564
# ph2060r  0.431368
# ph2082r  0.650642
# VE1006r  0.551540
# VE1017   0.442428
# VE1039   0.701637
# VE1061   0.801944
# VE1083   0.630896
# VE1099   0.631272
# SS1053   0.315358
# SS1075   0.458464
# SS1094   0.390289
# ss1020r  0.423168
# ss1042r  0.675716
# ss1064r  0.809803
# ss1086r  0.677541
# ss1101r  0.544423
#
#
# index <0.3 communalities
#
#
# ['MA1045']

# %% [markdown]
# *Item 6*

# %%
rmv_item = [*range(0,len(ft_comm), 1)]
df_rmv_eighth_item = df_rmv_seventh_item.drop(columns = ft_comm[rmv_item[0]])

communalities, ft_comm, comm_diagnosis,  des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(4, "oblimin", "ml", df_rmv_eighth_item)

to_print = [communalities, ft_comm]
label_to_print = ["communalities", "index <0.3 communalities"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.956073
# MA1012r  0.701181
# MA1023   0.480109
# MA1034r  0.617120
# MA1056r  0.606974
# MA1067   0.730747
# MA1078r  0.353773
# MA1089   0.735627
# MA1096r  0.486806
# PH2005   0.563554
# PH2027   0.732874
# PH2049   0.537047
# ph2016r  0.460308
# ph2038r  0.574879
# ph2060r  0.431057
# ph2082r  0.649999
# VE1006r  0.555607
# VE1017   0.420363
# VE1039   0.710482
# VE1061   0.806432
# VE1083   0.637632
# VE1099   0.635269
# SS1053   0.312570
# SS1075   0.458752
# SS1094   0.387631
# ss1020r  0.423246
# ss1042r  0.688468
# ss1064r  0.819830
# ss1086r  0.685282
# ss1101r  0.543815
#
#
# index <0.3 communalities
#
#
# []

# %% [markdown]
# ### Final solution after removing all items with low communalities

# %%
compute_determinant_corr(df_rmv_eighth_item)
compute_kmo(df_rmv_eighth_item)
compute_berlett(df_rmv_eighth_item)
# Out:
# 7.820865317889123e-11
# kmo score : 0.9397557261431313
# pval: 0.0 /chi_square: 12506.857089944775

# %%
communalities, ft_comm, comm_diagnosis,  des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor = evaluate_solution(4, "oblimin", "ml", df_rmv_eighth_item)

to_print = [communalities, ft_comm, comm_diagnosis, des_communalities, df_loadings, des_loadings, interpretability_diagnosis,diagnosis_quality_factors, saturation_diagnosis, factor_correlation_matrix, pattern_matrix, structure_matrix, reproduced_correlation_matrix, df_residuals, proportion_res, residuals_diagnosis, variance, variance_explained, variance_diagnosis, df_ev, df_uniqueness, count_items_per_factor]
label_to_print = ["communalities", "index comm < 0.3", "communalities diagnosis", "describe communalities",  "df_loadings", "describe loadings", "interpretability of factors", "quality of factors, items/factor" , "saturation_diagnosis", "factor_correlation_matrix", "pattern_matrix", "structure_matrix", "reproduced_correlation_matrix", "df_residuals", "proportion_residuals_over_0.05", "residuals_diagnosis", "variance", "variance_explained", "variance_diagnosis", "eigenvalues", "df_uniqueness", "count_items_per_factor"]

for i in range (0, len(to_print)):
  print("\n")
  print(label_to_print[i])
  print("\n")
  print(to_print[i])
# Out:
# communalities
#
#
#                 0
# MA1001   0.956073
# MA1012r  0.701181
# MA1023   0.480109
# MA1034r  0.617120
# MA1056r  0.606974
# MA1067   0.730747
# MA1078r  0.353773
# MA1089   0.735627
# MA1096r  0.486806
# PH2005   0.563554
# PH2027   0.732874
# PH2049   0.537047
# ph2016r  0.460308
# ph2038r  0.574879
# ph2060r  0.431057
# ph2082r  0.649999
# VE1006r  0.555607
# VE1017   0.420363
# VE1039   0.710482
# VE1061   0.806432
# VE1083   0.637632
# VE1099   0.635269
# SS1053   0.312570
# SS1075   0.458752
# SS1094   0.387631
# ss1020r  0.423246
# ss1042r  0.688468
# ss1064r  0.819830
# ss1086r  0.685282
# ss1101r  0.543815
#
#
# index comm < 0.3
#
#
# []
#
#
# communalities diagnosis
#
#
# Total variables with communalities < 0.3 :0
#
#
# describe communalities
#
#
# mean = 0.5901168959542229, min = 0.3125701899960571, max = 0.956073316038718)
#
#
# df_loadings
#
#
#               fa1       fa2       fa3       fa4 highest loading
# MA1001   0.969898 -0.122323 -0.020121 -0.001656             fa1
# MA1012r  0.827619  0.089644 -0.087774 -0.022092             fa1
# MA1023   0.683791 -0.091900  0.032961  0.054835             fa1
# MA1034r  0.776096  0.103860 -0.061498  0.015033             fa1
# MA1056r  0.743373  0.204261 -0.093462 -0.062558             fa1
# MA1067   0.852149  0.065133  0.018587  0.001317             fa1
# MA1078r  0.592474 -0.012030  0.038521  0.033456             fa1
# MA1089   0.853999 -0.021554  0.073808  0.020006             fa1
# MA1096r  0.695457 -0.002075  0.036512  0.042511             fa1
# ss1064r -0.041063  0.904466 -0.009154 -0.000494             fa2
# ss1042r -0.004765  0.829318  0.024796  0.007932             fa2
# ss1020r  0.111121  0.636561  0.068631  0.031265             fa2
# SS1094   0.237559  0.516858  0.252703 -0.013983             fa2
# SS1075   0.155869  0.639363  0.155916 -0.036900             fa2
# SS1053   0.275375  0.451011  0.182082  0.013205             fa2
# ss1101r  0.107960  0.726605  0.032099  0.056345             fa2
# ss1086r -0.003993  0.826901  0.036579  0.012794             fa2
# VE1006r -0.055623  0.026620  0.740054 -0.064218             fa3
# VE1017   0.021854 -0.062124  0.644959 -0.007317             fa3
# VE1039  -0.009919  0.007202  0.842800  0.004390             fa3
# VE1061  -0.032433 -0.085812  0.893137  0.017947             fa3
# VE1083   0.002498  0.154367  0.783450 -0.001562             fa3
# VE1099  -0.002361  0.157601  0.781095  0.017782             fa3
# ph2038r -0.030971  0.026710 -0.068901  0.753962             fa4
# ph2016r -0.054843  0.191053 -0.101414  0.640714             fa4
# PH2049   0.103376 -0.118407  0.076636  0.711665             fa4
# PH2027   0.032783 -0.114332  0.079056  0.844084             fa4
# PH2005  -0.000844 -0.064467  0.076109  0.744046             fa4
# ph2082r -0.028367  0.109253 -0.062729  0.795816             fa4
# ph2060r -0.009059  0.169898 -0.097210  0.626626             fa4
#
#
# describe loadings
#
#
# mean = 0.2034487650002347, min = -0.12232254047039678, max = 0.969898411694979)
#
#
# interpretability of factors
#
#
#
#
#
# quality of factors, items/factor
#
#
# There are 4 factors > 0.8 for fa1 ; There are 3 factors > 0.8 for fa2 ; There are 2 factors > 0.8 for fa3 ; There are 1 factors > 0.8 for fa4 ;
#
#
# saturation_diagnosis
#
#
# Pas de problème de saturations croisées
#
#
# factor_correlation_matrix
#
#
# [[ 1.          0.0582312   0.13791527  0.57990309]
#  [ 0.0582312   1.         -0.00865006  0.48300519]
#  [ 0.13791527 -0.00865006  1.          0.10648371]
#  [ 0.57990309  0.48300519  0.10648371  1.        ]]
#
#
# pattern_matrix
#
#
# [[ 9.69898412e-01 -1.22322540e-01 -2.01206191e-02 -1.65644502e-03]
#  [ 8.27618672e-01  8.96436809e-02 -8.77740309e-02 -2.20921205e-02]
#  [ 6.83790959e-01 -9.18995316e-02  3.29608594e-02  5.48348551e-02]
#  [ 7.76096158e-01  1.03859822e-01 -6.14975764e-02  1.50333589e-02]
#  [ 7.43372762e-01  2.04260672e-01 -9.34623930e-02 -6.25580392e-02]
#  [ 8.52148592e-01  6.51332463e-02  1.85867523e-02  1.31684061e-03]
#  [ 5.92473555e-01 -1.20304267e-02  3.85208894e-02  3.34562772e-02]
#  [ 8.53999273e-01 -2.15537804e-02  7.38081287e-02  2.00064770e-02]
#  [ 6.95457414e-01 -2.07478500e-03  3.65120053e-02  4.25106420e-02]
#  [-8.43786886e-04 -6.44674828e-02  7.61091767e-02  7.44046201e-01]
#  [ 3.27832218e-02 -1.14332380e-01  7.90564689e-02  8.44083920e-01]
#  [ 1.03376460e-01 -1.18407233e-01  7.66359504e-02  7.11664889e-01]
#  [-5.48429419e-02  1.91052713e-01 -1.01414157e-01  6.40713756e-01]
#  [-3.09705733e-02  2.67101204e-02 -6.89011626e-02  7.53961965e-01]
#  [-9.05919350e-03  1.69898050e-01 -9.72097316e-02  6.26626161e-01]
#  [-2.83672661e-02  1.09252631e-01 -6.27291593e-02  7.95816333e-01]
#  [-5.56225948e-02  2.66195997e-02  7.40054194e-01 -6.42181571e-02]
#  [ 2.18535458e-02 -6.21235074e-02  6.44959054e-01 -7.31744108e-03]
#  [-9.91903260e-03  7.20204545e-03  8.42800223e-01  4.38990759e-03]
#  [-3.24326894e-02 -8.58116524e-02  8.93137287e-01  1.79473998e-02]
#  [ 2.49795031e-03  1.54366920e-01  7.83450141e-01 -1.56158477e-03]
#  [-2.36072749e-03  1.57601302e-01  7.81094968e-01  1.77816193e-02]
#  [ 2.75374548e-01  4.51010971e-01  1.82081830e-01  1.32045145e-02]
# 27  0.335477  0.179498  0.119338  0.170804  0.063550  0.006601  0.184656
# 28  0.307453  0.169891  0.151951  0.216305  0.083267  0.012016  0.002851
# 29  0.285000  0.207590  0.117797  0.217704  0.128459  0.027546  0.020778
#
#           28        29
# 0   0.422747  0.311208
# 1   0.301651  0.286439
# 2   0.263570  0.236999
# 3   0.312175  0.283890
# 4   0.305902  0.254783
# 5   0.363034  0.294185
# 6   0.248826  0.214246
# 7   0.370134  0.316299
# 8   0.301593  0.242570
# 9  -0.206143 -0.212614
# 10 -0.212188 -0.230770
# 11 -0.130656 -0.197989
# 12 -0.266877 -0.270603
# 13 -0.272737 -0.282971
# 14 -0.250764 -0.222988
# 15 -0.299141 -0.286745
# 16  0.333469  0.207832
# 17  0.269209  0.226669
# 18  0.333889  0.269310
# 19  0.364931  0.287743
# 20  0.284350  0.294179
# 21  0.307453  0.285000
# 22  0.169891  0.207590
# 23  0.151951  0.117797
# 24  0.216305  0.217704
# 25  0.083267  0.128459
# 26  0.012016  0.027546
# 27  0.002851  0.020778
# 28  0.305405  0.050073
# 29  0.050073  0.399508
#
#
# proportion_residuals_over_0.05
#
#
# 0.19555555555555557
#
#
# residuals_diagnosis
#
#
# Pass,  less than 50% are > 0.05. Proportion = 0.19555555555555557
#
#
# variance
#
#
#                      fa1       fa2       fa3       fa4
# loadings        5.741950  4.260820  3.901318  3.799420
# proportion var  0.191398  0.142027  0.130044  0.126647
# cumulative var  0.191398  0.333426  0.463470  0.590117
#
#
# variance_explained
#
#
# 0.5901168959542231
#
#
# variance_diagnosis
#
#
# Factors explain more than 50% of common variance
#
#
# eigenvalues
#
#
#     eigenvalues
# 1     10.260406
# 2      4.784914
# 3      3.903310
# 4      1.443682
# 5      0.894781
# 6      0.709478
# 7      0.635804
# 8      0.592414
# 9      0.538913
# 10     0.500184
# 11     0.470510
# 12     0.456833
# 13     0.433077
# 14     0.398483
# 15     0.361502
# 16     0.351129
# 17     0.314717
# 18     0.313178
# 19     0.304501
# 20     0.282938
# 21     0.263070
# 22     0.249245
# 23     0.240113
# 24     0.220652
# 25     0.211854
# 26     0.192760
# 27     0.182575
# 28     0.178663
# 29     0.174361
# 30     0.135952
#
#
# df_uniqueness
#
#
#            0
# 0   0.043927
# 1   0.298819
# 2   0.519891
# 3   0.382880
# 4   0.393026
# 5   0.269253
# 6   0.646227
# 7   0.264373
# 8   0.513194
# 9   0.436446
# 10  0.267126
# 11  0.462953
# 12  0.539692
# 13  0.425121
# 14  0.568943
# 15  0.350001
# 16  0.444393
# 17  0.579637
# 18  0.289518
# 19  0.193568
# 20  0.362368
# 21  0.364731
# 22  0.687430
# 23  0.541248
# 24  0.612369
# 25  0.576754
# 26  0.311532
# 27  0.180170
# 28  0.314718
# 29  0.456185
#
#
# count_items_per_factor
#
#
#      highest loading
# fa1                9
# fa2                8
# fa4                7
# fa3                6

# %% [markdown]
# ### Interprétation

# %%
# Following oblique rotation, the meaning of factors is ascertained from the pattern matrix
#Les saturations plus élevées que .40 sont interprétées (16% de variance expliquée; Stevens 2002)
